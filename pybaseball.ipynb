# %%
from pybaseball import *

# %%
pitching = pitching_stats(2010, 2015)

# %%
pitching.head()
# Out:
#      Season             Name      Team   Age     W    L   ERA  WAR     G  \
# 381  2015.0  Clayton Kershaw   Dodgers  27.0  16.0  7.0  2.13  8.5  33.0
# 498  2011.0     Roy Halladay  Phillies  34.0  19.0  6.0  2.35  8.3  32.0
# 262  2014.0  Clayton Kershaw   Dodgers  26.0  21.0  3.0  1.77  7.6  27.0
# 541  2014.0     Corey Kluber   Indians  28.0  18.0  9.0  2.44  7.4  34.0
# 261  2015.0     Jake Arrieta      Cubs  29.0  22.0  6.0  1.77  7.3  33.0
#
#        GS    ...      wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  \
# 381  33.0    ...            1.76       22.85          0.364          0.665
# 498  32.0    ...             NaN         NaN          0.362          0.611
# 262  27.0    ...            2.62         NaN          0.371          0.670
# 541  34.0    ...            3.92         NaN          0.336          0.598
# 261  33.0    ...            2.42         NaN          0.329          0.618
#
# ...

# %%
for col in pitching.columns:
    print(col)
# Out:
# Season
# Name
# Team
# Age
# W
# L
# ERA
# WAR
# G
# GS
# CG
# ShO
# SV
# BS
# IP
# TBF
# H
# R
# ER
# HR
# BB
# IBB
# HBP
# WP
# BK
# SO
# GB
# FB
# LD
# IFFB
# Balls
# Strikes
# Pitches
# RS
# IFH
# BU
# BUH
# K/9
# BB/9
# K/BB
# H/9
# HR/9
# AVG
# WHIP
# BABIP
# LOB%
# FIP
# GB/FB
# LD%
# GB%
# IFFB%
# HR/FB
# IFH%
# BUH%
# Starting
# Start-IP
# Relieving
# Relief-IP
# RAR
# Dollars
# tERA
# xFIP
# WPA
# -WPA
# +WPA
# RE24
# REW
# pLI
# inLI
# gmLI
# exLI
# Pulls
# WPA/LI
# Clutch
# FB%
# FBv
# SL%
# SLv
# CT%
# CTv
# CB%
# CBv
# CH%
# CHv
# SF%
# SFv
# KN%
# KNv
# XX%
# PO%
# wFB
# wSL
# wCT
# wCB
# wCH
# wSF
# wKN
# wFB/C
# wSL/C
# wCT/C
# wCB/C
# wCH/C
# wSF/C
# wKN/C
# O-Swing%
# Z-Swing%
# Swing%
# O-Contact%
# Z-Contact%
# Contact%
# Zone%
# F-Strike%
# SwStr%
# HLD
# SD
# MD
# ERA-
# FIP-
# xFIP-
# K%
# BB%
# SIERA
# RS/9
# E-F
# FA% (pfx)
# FT% (pfx)
# FC% (pfx)
# FS% (pfx)
# FO% (pfx)
# SI% (pfx)
# SL% (pfx)
# CU% (pfx)
# KC% (pfx)
# EP% (pfx)
# CH% (pfx)
# SC% (pfx)
# ...
