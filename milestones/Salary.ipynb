# %%
# %matplotlib inline
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
player = pd.read_csv('data/baseball/player.csv', usecols=[0,1,13,14,15,16,17,18,19,20,21])
salary = pd.read_csv('data/baseball/salary.csv')
appearances = pd.read_csv('data/baseball/appearances.csv')
batting = pd.read_csv('data/baseball/batting.csv')
fielding = pd.read_csv('data/baseball/fielding.csv')
team = pd.read_csv('data/baseball/team.csv')
pitching = pd.read_csv('data/baseball/pitching.csv')

# %%
app_player = appearances.merge(player).sort_values(by=['year', 'team_id', 'player_id']).reset_index()

# %%
app_player['age'] = app_player.year - app_player.birth_year
app_player['years_in_mlb'] = app_player.year - app_player.debut.dropna().str[0:4].astype(int)

# %%
appearances['age'] = app_player.age
appearances['years_in_mlb'] = app_player.years_in_mlb

# %% [markdown]
# For the project, we are looking at the importance of salary for building a baseball team.

# %% [markdown]
# ### Salary Over Time

# %%
(salary.groupby(['year', 'team_id']).sum().groupby('year')['salary'].median() / 1000000).plot(
                                                title='Median Log Team Salaries (in millions)\n1985-2015')

# %%
(salary[salary.league_id == 'AL'].groupby(['year', 'team_id']).size().groupby('year').median()).plot()
(salary[salary.league_id == 'NL'].groupby(['year', 'team_id']).size().groupby('year').median()).plot()

# %%
salary[salary.year == 2015].groupby('team_id')['salary'].sum().median() / salary[salary.year == 1985].groupby('team_id')['salary'].sum().median()
# Out:
# 11.202202483475384

# %%
(salary.groupby('year')['salary'].median() / 1000).plot(title='Median Individual Salaries (in thousands)\n1985-2015')

# %%
for year in range(2011, 2016):
    stats = salary[(salary.league_id == 'AL') & (salary.year == year)].groupby(['team_id'])['salary'].sum().describe()
    print(f'{year}:\n{stats}\n')
# Out:
# 2011:
# count    1.400000e+01
# mean     9.765480e+07
# std      4.793501e+07
# min      3.571200e+07
# 25%      6.355998e+07
# 50%      8.920493e+07
# 75%      1.240260e+08
# max      2.022750e+08
# Name: salary, dtype: float64
#
# 2012:
# count    1.400000e+01
# mean     1.043745e+08
# std      4.438653e+07
# min      5.537250e+07
# 25%      7.559540e+07
# 50%      8.803155e+07
# 75%      1.293527e+08
# max      1.965223e+08
# Name: salary, dtype: float64
#
# 2013:
# count    1.500000e+01
# mean     1.022085e+08
# std      5.141290e+07
# min      1.789070e+07
# 25%      7.467127e+07
# 50%      8.439333e+07
# 75%      1.252314e+08
# max      2.319789e+08
# Name: salary, dtype: float64
#
# 2014:
# count    1.500000e+01
# mean     1.018388e+08
# std      3.967335e+07
# min      3.511630e+07
# 25%      7.612299e+07
# 50%      9.253110e+07
# 75%      1.171217e+08
# max      1.975439e+08
# Name: salary, dtype: float64
#
# 2015:
# count    1.600000e+01
# mean     1.137962e+08
# std      4.946412e+07
# min      4.875000e+06
# 25%      8.551120e+07
# 50%      1.126830e+08
# 75%      1.275922e+08
# max      2.127520e+08
# Name: salary, dtype: float64

# %%
for year in range(2011, 2016):
    stats = salary[(salary.league_id == 'NL') & (salary.year == year)].groupby(['team_id'])['salary'].sum().describe()
    print(f'{year}:\n{stats}\n')
# Out:
# 2011:
# count    1.600000e+01
# mean     8.858363e+07
# std      3.446501e+07
# min      4.504700e+07
# 25%      6.212870e+07
# 50%      8.625001e+07
# 75%      1.086248e+08
# max      1.729764e+08
# Name: salary, dtype: float64
#
# 2012:
# count    1.600000e+01
# mean     9.196861e+07
# std      2.892415e+07
# min      5.524470e+07
# 25%      7.700339e+07
# 50%      8.551349e+07
# 75%      1.008157e+08
# max      1.745389e+08
# Name: salary, dtype: float64
#
# 2013:
# count    1.500000e+01
# mean     1.000932e+08
# std      4.788972e+07
# min      3.360190e+07
# 25%      7.567805e+07
# 50%      9.013200e+07
# 75%      1.100539e+08
# max      2.233622e+08
# Name: salary, dtype: float64
#
# 2014:
# count    1.600000e+01
# mean     1.040459e+08
# std      5.201297e+07
# min      4.500000e+06
# 25%      7.680492e+07
# 50%      9.773525e+07
# 75%      1.235157e+08
# max      2.170146e+08
# Name: salary, dtype: float64
#
# 2015:
# count    1.500000e+01
# mean     1.128935e+08
# std      4.078062e+07
# min      5.695900e+07
# 25%      9.229055e+07
# 50%      1.116930e+08
# 75%      1.188414e+08
# max      2.157920e+08
# Name: salary, dtype: float64

# %% [markdown]
# ### Distributions
#
# #### By year (individual players)

# %%
salary_app = salary.merge(appearances)

# %%
np.log(salary.groupby('player_id')['salary'].mean()).plot(kind='hist', bins=12, title='Log of mean salaries')

# %%
def distribution_salary(year,starters=False):
    if starters:
        np.log(salary_app[(salary_app.year == year) & (salary_app.gs > 80)].salary).plot(
            kind='hist', bins=20, title=f'Log salaries for starters in {year}')
    else:
        np.log(salary[(salary.year == year)].salary).plot(kind='hist', bins=20, title=f'Log salaries in {year}')

# %%
distribution_salary(2015,starters=True)

# %%
distribution_salary(2005)

# %%
distribution_salary(1995)

# %%
distribution_salary(1985)

# %% [markdown]
# 1985 is the only year in which the distributions of individual salaries appears to be fairly normal.

# %% [markdown]
# #### By year (team totals)

# %%
team_salary = team.merge(salary)
winners = team_salary[(team_salary.w / team_salary.l) >= 1]
losers = team_salary[(team_salary.w / team_salary.l) < 1]

# %%
def distribution_team_salary(year):
    np.log(winners[(winners.year == year)].groupby('team_id')['salary'].sum()).plot(
        kind='hist', bins=8, title=f'Log team salaries {year}', alpha=0.5)
    np.log(losers[(losers.year == year)].groupby('team_id')['salary'].sum()).plot(
        kind='hist', bins=8, title=f'Log team salaries {year}', alpha=0.5)

# %% [markdown]
# Blue bars represent teams with a record better than .500, orange bars are teams with less than .500.

# %%
distribution_team_salary(1985)

# %%
distribution_team_salary(1995)

# %%
distribution_team_salary(2005)

# %%
distribution_team_salary(2015)

# %%
(salary[salary.year == 2015].groupby('team_id')['salary'].sum() / 1000000).describe()

# %% [markdown]
# ### Scatterplots and Regressions
#
# #### Do Higher Team Salaries Translate to More Wins?

# %%
team_salary = team.merge(salary).drop(1994)

# %%
def salary_year(year):
    team_salary_year = team_salary[team_salary.year == year]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_total = team_salary_year.groupby('team_id')['salary'].sum()
    rel_salary_total = (salary_total - salary_total.mean()) / salary_total.std()
    ws = team_salary_year[team_salary_year.ws_win == 'Y']
    ws_salary = (ws.groupby('team_id')['salary'].sum() - salary_total.mean()) / salary_total.std()
    ws_wins = ws.groupby('team_id')['w'].median()
    return wins, salary_total

# %%
def wins_salary_graph(year):
    wins, salary_total = salary_year(year)
    plt.scatter(salary_total, wins)
    plt.ylabel("Team wins")
    plt.xlabel("Difference in team salary from mean by std")
    plt.title(f"How does salary impact wins?\n{year} season")

# %%
def salary_total():
    wins = team_salary.groupby(['year','team_id'])['w'].median().reset_index('year').drop('year',axis=1)
    salary_total = team_salary.groupby(['year','team_id'])['salary'].sum()
    rel_salary_total = (salary_total.xs(1985) - salary_total.xs(1985).mean()) / salary_total.xs(1985).std()
    for year in range(1986,2016):
        rel_salary = (salary_total.xs(year) - salary_total.xs(year).mean()) / salary_total.xs(year).std()
        rel_salary_total = pd.concat([rel_salary_total,rel_salary])
    return wins, rel_salary_total

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# /Users/jnelson/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# For all years
y, X = salary_total()
X = sm.add_constant(X)
results = smf.OLS(y, X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     109.4
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):           3.19e-24
# Time:                        16:40:25   Log-Likelihood:                -3405.6
# No. Observations:                 888   AIC:                             6815.
# Df Residuals:                     886   BIC:                             6825.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         79.9110      0.376    212.307      0.000      79.172      80.650
# salary         4.0075      0.383     10.459      0.000       3.255       4.759
# ==============================================================================
# Omnibus:                       10.572   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.703
# Skew:                          -0.253   Prob(JB):                      0.00474
# Kurtosis:                       2.820   Cond. No.                         1.02
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
wins, salary_total = salary_total()
plt.scatter(salary_total, wins, alpha=0.4)

# %%
(team_salary[(team_salary.year == 2015)].groupby(['year', 'team_id'])['salary'].sum() / 1000000).describe()
# Out:
# count     30.000000
# mean     116.975586
# std       40.611048
# min       56.959000
# 25%       90.591524
# 50%      112.683050
# 75%      121.657879
# max      215.792000
# Name: salary, dtype: float64

# %%
for year in range(1985, 2016):
    y, X = salary_year(year)
    X = np.log(X)
    X = sm.add_constant(X)
    results = smf.OLS(y, X).fit()
    print(f'\nFor {year}:\n{results.summary()}')
# Out:
# For 1985:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     3.505
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0734
# Time:                        16:40:26   Log-Likelihood:                -100.43
# No. Observations:                  26   AIC:                             204.9
# Df Residuals:                      24   BIC:                             207.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -187.4236    143.288     -1.308      0.203    -483.155     108.308
# salary        16.6673      8.902      1.872      0.073      -1.706      35.041
# ==============================================================================
# Omnibus:                        1.107   Durbin-Watson:                   2.194
# Prob(Omnibus):                  0.575   Jarque-Bera (JB):                1.028
# Skew:                          -0.324   Prob(JB):                        0.598
# Kurtosis:                       2.272   Cond. No.                         985.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1986:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.206
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.283
# Time:                        16:40:26   Log-Likelihood:                -96.298
# No. Observations:                  26   AIC:                             196.6
# Df Residuals:                      24   BIC:                             199.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -49.5747    118.766     -0.417      0.680    -294.696     195.547
# salary         8.0256      7.307      1.098      0.283      -7.056      23.107
# ==============================================================================
# Omnibus:                        1.248   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.536   Jarque-Bera (JB):                0.985
# Skew:                           0.457   Prob(JB):                        0.611
# Kurtosis:                       2.729   Cond. No.                         966.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1987:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                   0.03132
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.861
# Time:                        16:40:26   Log-Likelihood:                -95.826
# No. Observations:                  26   AIC:                             195.7
# Df Residuals:                      24   BIC:                             198.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         71.8787     51.362      1.399      0.174     -34.128     177.885
# salary         0.5662      3.199      0.177      0.861      -6.037       7.169
# ==============================================================================
# Omnibus:                        0.564   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.754   Jarque-Bera (JB):                0.630
# Skew:                          -0.105   Prob(JB):                        0.730
# Kurtosis:                       2.267   Cond. No.                         420.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1988:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.6489
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.428
# Time:                        16:40:26   Log-Likelihood:                -100.71
# No. Observations:                  26   AIC:                             205.4
# Df Residuals:                      24   BIC:                             207.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -18.1151    122.684     -0.148      0.884    -271.322     235.092
# salary         6.0930      7.564      0.806      0.428      -9.518      21.704
# ==============================================================================
# Omnibus:                        3.917   Durbin-Watson:                   1.429
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.266
# Skew:                          -0.639   Prob(JB):                        0.322
# Kurtosis:                       3.676   Cond. No.                         841.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1989:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     3.449
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0756
# Time:                        16:40:26   Log-Likelihood:                -94.476
# No. Observations:                  26   AIC:                             193.0
# Df Residuals:                      24   BIC:                             195.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -132.7017    115.019     -1.154      0.260    -370.088     104.685
# salary        13.0161      7.008      1.857      0.076      -1.448      27.481
# ==============================================================================
# Omnibus:                        1.417   Durbin-Watson:                   2.376
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                0.760
# Skew:                          -0.418   Prob(JB):                        0.684
# Kurtosis:                       3.063   Cond. No.                     1.01e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1990:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                  0.002498
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.961
# Time:                        16:40:26   Log-Likelihood:                -93.713
# No. Observations:                  26   AIC:                             191.4
# Df Residuals:                      24   BIC:                             193.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         87.3767    128.378      0.681      0.503    -177.582     352.335
# salary        -0.3858      7.720     -0.050      0.961     -16.320      15.548
# ==============================================================================
# Omnibus:                        1.396   Durbin-Watson:                   2.199
# Prob(Omnibus):                  0.498   Jarque-Bera (JB):                1.023
# Skew:                           0.476   Prob(JB):                        0.600
# Kurtosis:                       2.805   Cond. No.                     1.18e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1991:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     2.061
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.164
# Time:                        16:40:26   Log-Likelihood:                -94.417
# No. Observations:                  26   AIC:                             192.8
# Df Residuals:                      24   BIC:                             195.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -69.3722    104.696     -0.663      0.514    -285.454     146.710
# salary         8.8762      6.182      1.436      0.164      -3.883      21.636
# ==============================================================================
# Omnibus:                        0.120   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.942   Jarque-Bera (JB):                0.221
# Skew:                          -0.140   Prob(JB):                        0.895
# Kurtosis:                       2.646   Cond. No.                         954.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1992:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                   0.07768
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.783
# Time:                        16:40:26   Log-Likelihood:                -96.768
# No. Observations:                  26   AIC:                             197.5
# Df Residuals:                      24   BIC:                             200.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         53.4229     98.967      0.540      0.594    -150.834     257.680
# salary         1.6038      5.754      0.279      0.783     -10.272      13.480
# ==============================================================================
# Omnibus:                        2.880   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.237   Jarque-Bera (JB):                1.303
# Skew:                           0.035   Prob(JB):                        0.521
# Kurtosis:                       1.906   Cond. No.                         836.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1993:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     3.684
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0660
# Time:                        16:40:26   Log-Likelihood:                -107.30
# No. Observations:                  28   AIC:                             218.6
# Df Residuals:                      26   BIC:                             221.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -134.4965    112.289     -1.198      0.242    -365.310      96.317
# salary        12.5011      6.513      1.919      0.066      -0.886      25.888
# ==============================================================================
# Omnibus:                        0.005   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.998   Jarque-Bera (JB):                0.147
# Skew:                          -0.026   Prob(JB):                        0.929
# Kurtosis:                       2.649   Cond. No.                         887.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1994:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     3.868
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0600
# Time:                        16:40:26   Log-Likelihood:                -94.060
# No. Observations:                  28   AIC:                             192.1
# Df Residuals:                      26   BIC:                             194.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -109.7183     84.840     -1.293      0.207    -284.109      64.673
# salary         9.6541      4.909      1.967      0.060      -0.437      19.745
# ==============================================================================
# Omnibus:                        9.859   Durbin-Watson:                   1.569
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                8.199
# Skew:                           1.171   Prob(JB):                       0.0166
# Kurtosis:                       4.242   Cond. No.                     1.08e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1995:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     3.629
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0679
# Time:                        16:40:26   Log-Likelihood:                -102.59
# No. Observations:                  28   AIC:                             209.2
# Df Residuals:                      26   BIC:                             211.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -120.3246    100.978     -1.192      0.244    -327.887      87.238
# salary        11.1193      5.837      1.905      0.068      -0.879      23.117
# ==============================================================================
# Omnibus:                        2.733   Durbin-Watson:                   1.554
# Prob(Omnibus):                  0.255   Jarque-Bera (JB):                1.353
# Skew:                           0.348   Prob(JB):                        0.508
# Kurtosis:                       3.821   Cond. No.                         947.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1996:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     8.617
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):            0.00688
# Time:                        16:40:26   Log-Likelihood:                -99.665
# No. Observations:                  28   AIC:                             203.3
# Df Residuals:                      26   BIC:                             206.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -184.3578     90.388     -2.040      0.052    -370.153       1.437
# salary        15.3365      5.225      2.935      0.007       4.597      26.076
# ==============================================================================
# Omnibus:                        3.267   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.195   Jarque-Bera (JB):                1.798
# Skew:                          -0.527   Prob(JB):                        0.407
# Kurtosis:                       3.657   Cond. No.                         941.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1997:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     3.830
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0612
# Time:                        16:40:26   Log-Likelihood:                -100.65
# No. Observations:                  28   AIC:                             205.3
# Df Residuals:                      26   BIC:                             208.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -66.7526     75.485     -0.884      0.385    -221.915      88.409
# salary         8.4661      4.326      1.957      0.061      -0.427      17.359
# ==============================================================================
# Omnibus:                        3.538   Durbin-Watson:                   1.607
# Prob(Omnibus):                  0.171   Jarque-Bera (JB):                1.461
# Skew:                          -0.023   Prob(JB):                        0.482
# Kurtosis:                       1.882   Cond. No.                         765.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1998:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.385
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     17.56
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):           0.000252
# Time:                        16:40:26   Log-Likelihood:                -112.90
# No. Observations:                  30   AIC:                             229.8
# Df Residuals:                      28   BIC:                             232.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -249.0007     78.784     -3.161      0.004    -410.382     -87.620
# salary        18.8720      4.504      4.190      0.000       9.646      28.098
# ==============================================================================
# Omnibus:                        1.357   Durbin-Watson:                   2.531
# Prob(Omnibus):                  0.507   Jarque-Bera (JB):                0.398
# Skew:                          -0.067   Prob(JB):                        0.819
# Kurtosis:                       3.548   Cond. No.                         702.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1999:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.312
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     12.73
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):            0.00132
# Time:                        16:40:26   Log-Likelihood:                -112.25
# No. Observations:                  30   AIC:                             228.5
# Df Residuals:                      28   BIC:                             231.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -184.8675     74.526     -2.481      0.019    -337.528     -32.207
# salary        15.0763      4.226      3.567      0.001       6.419      23.733
# ==============================================================================
# Omnibus:                        4.309   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                1.659
# Skew:                           0.088   Prob(JB):                        0.436
# Kurtosis:                       1.861   Cond. No.                         684.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2000:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     3.141
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0872
# Time:                        16:40:26   Log-Likelihood:                -109.50
# No. Observations:                  30   AIC:                             223.0
# Df Residuals:                      28   BIC:                             225.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -42.3212     69.572     -0.608      0.548    -184.832     100.190
# salary         6.9463      3.920      1.772      0.087      -1.083      14.975
# ==============================================================================
# Omnibus:                        1.417   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                0.961
# Skew:                          -0.001   Prob(JB):                        0.619
# Kurtosis:                       2.123   Cond. No.                         704.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2001:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     2.385
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.134
# Time:                        16:40:26   Log-Likelihood:                -117.80
# No. Observations:                  30   AIC:                             239.6
# Df Residuals:                      28   BIC:                             242.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -80.9674    104.869     -0.772      0.447    -295.781     133.846
# salary         9.0342      5.850      1.544      0.134      -2.950      21.018
# ==============================================================================
# Omnibus:                        3.005   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.223   Jarque-Bera (JB):                1.872
# Skew:                           0.593   Prob(JB):                        0.392
# Kurtosis:                       3.302   Cond. No.                         813.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2002:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     6.086
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0200
# Time:                        16:40:26   Log-Likelihood:                -119.85
# No. Observations:                  30   AIC:                             243.7
# Df Residuals:                      28   BIC:                             246.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -227.6366    125.062     -1.820      0.079    -483.815      28.542
# salary        17.1721      6.961      2.467      0.020       2.914      31.430
# ==============================================================================
# Omnibus:                        0.577   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.749   Jarque-Bera (JB):                0.651
# Skew:                           0.112   Prob(JB):                        0.722
# Kurtosis:                       2.314   Cond. No.                         907.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2003:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     6.733
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0149
# Time:                        16:40:26   Log-Likelihood:                -116.61
# No. Observations:                  30   AIC:                             237.2
# Df Residuals:                      28   BIC:                             240.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -177.8648     99.777     -1.783      0.085    -382.249      26.519
# salary        14.3789      5.542      2.595      0.015       3.028      25.730
# ==============================================================================
# Omnibus:                        5.189   Durbin-Watson:                   2.323
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                3.681
# Skew:                          -0.820   Prob(JB):                        0.159
# Kurtosis:                       3.504   Cond. No.                         808.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2004:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.268
# Method:                 Least Squares   F-statistic:                     11.61
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):            0.00201
# Time:                        16:40:26   Log-Likelihood:                -115.04
# No. Observations:                  30   AIC:                             234.1
# Df Residuals:                      28   BIC:                             236.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -215.8706     87.137     -2.477      0.020    -394.363     -37.379
# salary        16.5321      4.852      3.407      0.002       6.593      26.471
# ==============================================================================
# Omnibus:                        7.224   Durbin-Watson:                   2.639
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                5.616
# Skew:                          -1.003   Prob(JB):                       0.0603
# Kurtosis:                       3.682   Cond. No.                         742.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2005:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     10.94
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):            0.00259
# Time:                        16:40:26   Log-Likelihood:                -108.59
# No. Observations:                  30   AIC:                             221.2
# Df Residuals:                      28   BIC:                             224.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -171.1024     76.245     -2.244      0.033    -327.284     -14.921
# salary        13.9903      4.230      3.307      0.003       5.325      22.655
# ==============================================================================
# Omnibus:                        0.426   Durbin-Watson:                   2.643
# Prob(Omnibus):                  0.808   Jarque-Bera (JB):                0.560
# Skew:                           0.078   Prob(JB):                        0.756
# Kurtosis:                       2.349   Cond. No.                         808.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2006:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     9.044
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):            0.00552
# Time:                        16:40:26   Log-Likelihood:                -107.19
# No. Observations:                  30   AIC:                             218.4
# Df Residuals:                      28   BIC:                             221.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -116.3826     65.644     -1.773      0.087    -250.848      18.082
# salary        10.9177      3.630      3.007      0.006       3.481      18.354
# ==============================================================================
# Omnibus:                        0.193   Durbin-Watson:                   1.741
# Prob(Omnibus):                  0.908   Jarque-Bera (JB):                0.402
# Skew:                          -0.017   Prob(JB):                        0.818
# Kurtosis:                       2.434   Cond. No.                         731.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2007:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     8.984
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):            0.00565
# Time:                        16:40:26   Log-Likelihood:                -104.77
# No. Observations:                  30   AIC:                             213.5
# Df Residuals:                      28   BIC:                             216.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -105.5301     62.262     -1.695      0.101    -233.068      22.008
# salary        10.2838      3.431      2.997      0.006       3.256      17.312
# ==============================================================================
# Omnibus:                        0.572   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.751   Jarque-Bera (JB):                0.658
# Skew:                           0.140   Prob(JB):                        0.720
# Kurtosis:                       2.331   Cond. No.                         754.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2008:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     2.220
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.147
# Time:                        16:40:26   Log-Likelihood:                -113.08
# No. Observations:                  30   AIC:                             230.2
# Df Residuals:                      28   BIC:                             233.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -41.6082     82.274     -0.506      0.617    -210.138     126.922
# salary         6.7255      4.514      1.490      0.147      -2.521      15.972
# ==============================================================================
# Omnibus:                        0.610   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.737   Jarque-Bera (JB):                0.711
# Skew:                          -0.235   Prob(JB):                        0.701
# Kurtosis:                       2.411   Cond. No.                         759.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2009:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     7.302
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0116
# Time:                        16:40:26   Log-Likelihood:                -111.68
# No. Observations:                  30   AIC:                             227.4
# Df Residuals:                      28   BIC:                             230.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -180.4254     96.766     -1.865      0.073    -378.641      17.790
# salary        14.3341      5.305      2.702      0.012       3.468      25.200
# ==============================================================================
# Omnibus:                        3.362   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.186   Jarque-Bera (JB):                1.817
# Skew:                          -0.321   Prob(JB):                        0.403
# Kurtosis:                       1.979   Cond. No.                         936.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2010:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     4.355
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0461
# Time:                        16:40:26   Log-Likelihood:                -111.84
# No. Observations:                  30   AIC:                             227.7
# Df Residuals:                      28   BIC:                             230.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -100.8202     87.142     -1.157      0.257    -279.322      77.682
# salary         9.9661      4.775      2.087      0.046       0.184      19.748
# ==============================================================================
# Omnibus:                        2.665   Durbin-Watson:                   2.651
# Prob(Omnibus):                  0.264   Jarque-Bera (JB):                1.368
# Skew:                          -0.141   Prob(JB):                        0.505
# Kurtosis:                       1.993   Cond. No.                         839.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2011:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     4.029
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0545
# Time:                        16:40:26   Log-Likelihood:                -113.09
# No. Observations:                  30   AIC:                             230.2
# Df Residuals:                      28   BIC:                             233.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -85.7747     83.089     -1.032      0.311    -255.975      84.426
# salary         9.1349      4.551      2.007      0.054      -0.187      18.457
# ==============================================================================
# Omnibus:                        0.432   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.806   Jarque-Bera (JB):                0.562
# Skew:                          -0.226   Prob(JB):                        0.755
# Kurtosis:                       2.505   Cond. No.                         767.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2012:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.110
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.301
# Time:                        16:40:26   Log-Likelihood:                -115.86
# No. Observations:                  30   AIC:                             235.7
# Df Residuals:                      28   BIC:                             238.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -44.0449    118.712     -0.371      0.713    -287.215     199.125
# salary         6.8188      6.472      1.054      0.301      -6.439      20.077
# ==============================================================================
# Omnibus:                        2.760   Durbin-Watson:                   2.430
# Prob(Omnibus):                  0.252   Jarque-Bera (JB):                1.564
# Skew:                          -0.267   Prob(JB):                        0.458
# Kurtosis:                       2.017   Cond. No.                     1.00e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2013:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     6.103
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0199
# Time:                        16:40:27   Log-Likelihood:                -114.28
# No. Observations:                  30   AIC:                             232.6
# Df Residuals:                      28   BIC:                             235.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -100.1661     73.378     -1.365      0.183    -250.473      50.141
# salary         9.8943      4.005      2.470      0.020       1.690      18.098
# ==============================================================================
# Omnibus:                        3.576   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.167   Jarque-Bera (JB):                1.496
# Skew:                           0.022   Prob(JB):                        0.473
# Kurtosis:                       1.907   Cond. No.                         654.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2014:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     3.404
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):             0.0757
# Time:                        16:40:27   Log-Likelihood:                -108.19
# No. Observations:                  30   AIC:                             220.4
# Df Residuals:                      28   BIC:                             223.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -62.5709     77.840     -0.804      0.428    -222.019      96.878
# salary         7.8007      4.228      1.845      0.076      -0.861      16.462
# ==============================================================================
# Omnibus:                        1.531   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.465   Jarque-Bera (JB):                1.116
# Skew:                          -0.207   Prob(JB):                        0.572
# Kurtosis:                       2.151   Cond. No.                         853.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2015:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.767
# Date:                Fri, 17 Nov 2017   Prob (F-statistic):              0.194
# Time:                        16:40:27   Log-Likelihood:                -111.55
# No. Observations:                  30   AIC:                             227.1
# Df Residuals:                      28   BIC:                             229.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -59.1532    105.419     -0.561      0.579    -275.094     156.788
# salary         7.5649      5.691      1.329      0.194      -4.092      19.222
# ==============================================================================
# Omnibus:                        1.067   Durbin-Watson:                   2.247
# Prob(Omnibus):                  0.586   Jarque-Bera (JB):                0.882
# Skew:                           0.134   Prob(JB):                        0.643
# Kurtosis:                       2.204   Cond. No.                     1.04e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
wins_salary_graph(1996)

# %%
wins_salary_graph(2015)

# %% [markdown]
# #### What about the spread of salaries?

# %%
def salary_dist_year(year):
    team_salary_year = team_salary[team_salary.year == year]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_total = team_salary_year.groupby('team_id')['salary'].sum()
    salary_dist = team_salary_year.groupby('team_id')['salary'].std()
    return wins, salary_total, salary_dist

# %%
for year in range(1985, 2016):
    y, X1, X2 = salary_dist_year(year)
    X = pd.concat([X1,X2],axis=1)
    X = np.log(X)
    X = sm.add_constant(X)
    results = smf.OLS(y, X).fit()
    print(f'\nFor {year}:\n{results.summary()}')
# Out:
# For 1985:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     2.390
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.114
# Time:                        12:29:05   Log-Likelihood:                -99.749
# No. Observations:                  26   AIC:                             205.5
# Df Residuals:                      23   BIC:                             209.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -193.4270    142.681     -1.356      0.188    -488.585     101.731
# salary         5.1599     13.613      0.379      0.708     -23.002      33.322
# salary        15.1058     13.570      1.113      0.277     -12.965      43.177
# ==============================================================================
# Omnibus:                        1.239   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.538   Jarque-Bera (JB):                1.168
# Skew:                          -0.436   Prob(JB):                        0.558
# Kurtosis:                       2.436   Cond. No.                     1.25e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1986:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     1.215
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.315
# Time:                        12:29:05   Log-Likelihood:                -95.630
# No. Observations:                  26   AIC:                             197.3
# Df Residuals:                      23   BIC:                             201.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -53.8427    118.308     -0.455      0.653    -298.581     190.895
# salary        -2.3513     11.905     -0.198      0.845     -26.980      22.277
# salary        13.5098     12.269      1.101      0.282     -11.871      38.891
# ==============================================================================
# Omnibus:                        0.934   Durbin-Watson:                   1.539
# Prob(Omnibus):                  0.627   Jarque-Bera (JB):                0.821
# Skew:                           0.162   Prob(JB):                        0.663
# Kurtosis:                       2.192   Cond. No.                     1.23e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.23e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1987:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.066
# Method:                 Least Squares   F-statistic:                    0.2270
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.799
# Time:                        12:29:05   Log-Likelihood:                -95.589
# No. Observations:                  26   AIC:                             197.2
# Df Residuals:                      23   BIC:                             201.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.7487    107.373      0.100      0.921    -211.369     232.867
# salary        -1.3586      4.386     -0.310      0.760     -10.432       7.715
# salary         7.1359     10.967      0.651      0.522     -15.550      29.822
# ==============================================================================
# Omnibus:                        1.273   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.529   Jarque-Bera (JB):                0.888
# Skew:                          -0.013   Prob(JB):                        0.641
# Kurtosis:                       2.095   Cond. No.                     1.11e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1988:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                 -0.032
# Method:                 Least Squares   F-statistic:                    0.6176
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.548
# Time:                        12:29:05   Log-Likelihood:                -100.37
# No. Observations:                  26   AIC:                             206.7
# Df Residuals:                      23   BIC:                             210.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -40.2424    126.996     -0.317      0.754    -302.954     222.470
# salary        16.6735     15.673      1.064      0.298     -15.749      49.096
# salary       -11.5728     14.976     -0.773      0.448     -42.552      19.406
# ==============================================================================
# Omnibus:                        2.756   Durbin-Watson:                   1.424
# Prob(Omnibus):                  0.252   Jarque-Bera (JB):                1.442
# Skew:                          -0.529   Prob(JB):                        0.486
# Kurtosis:                       3.462   Cond. No.                     1.10e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1989:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     1.662
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.212
# Time:                        12:29:05   Log-Likelihood:                -94.467
# No. Observations:                  26   AIC:                             194.9
# Df Residuals:                      23   BIC:                             198.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -135.9529    120.075     -1.132      0.269    -384.346     112.440
# salary        11.9898     10.647      1.126      0.272     -10.035      34.015
# salary         1.5304     11.755      0.130      0.898     -22.786      25.847
# ==============================================================================
# Omnibus:                        1.476   Durbin-Watson:                   2.372
# Prob(Omnibus):                  0.478   Jarque-Bera (JB):                0.800
# Skew:                          -0.428   Prob(JB):                        0.670
# Kurtosis:                       3.067   Cond. No.                     1.33e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1990:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                    0.2669
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.768
# Time:                        12:29:05   Log-Likelihood:                -93.416
# No. Observations:                  26   AIC:                             192.8
# Df Residuals:                      23   BIC:                             196.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.3595    129.912      0.626      0.537    -187.385     350.104
# salary         8.0054     13.903      0.576      0.570     -20.756      36.767
# salary       -10.1377     13.907     -0.729      0.473     -38.907      18.632
# ==============================================================================
# Omnibus:                        1.341   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.511   Jarque-Bera (JB):                1.103
# Skew:                           0.479   Prob(JB):                        0.576
# Kurtosis:                       2.681   Cond. No.                     1.51e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1991:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.010
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.380
# Time:                        12:29:05   Log-Likelihood:                -94.394
# No. Observations:                  26   AIC:                             194.8
# Df Residuals:                      23   BIC:                             198.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -51.8560    136.938     -0.379      0.708    -335.133     231.421
# salary         9.9760      8.290      1.203      0.241      -7.173      27.125
# salary        -2.6361     12.889     -0.205      0.840     -29.299      24.027
# ==============================================================================
# Omnibus:                        0.209   Durbin-Watson:                   1.616
# Prob(Omnibus):                  0.901   Jarque-Bera (JB):                0.226
# Skew:                          -0.177   Prob(JB):                        0.893
# Kurtosis:                       2.713   Cond. No.                     1.57e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1992:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.083
# Method:                 Least Squares   F-statistic:                   0.04402
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.957
# Time:                        12:29:05   Log-Likelihood:                -96.760
# No. Observations:                  26   AIC:                             199.5
# Df Residuals:                      23   BIC:                             203.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.9023    115.542      0.406      0.689    -192.115     285.920
# salary         3.1055     14.172      0.219      0.828     -26.212      32.423
# salary        -1.3919     11.953     -0.116      0.908     -26.119      23.336
# ==============================================================================
# Omnibus:                        2.934   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.231   Jarque-Bera (JB):                1.311
# Skew:                           0.017   Prob(JB):                        0.519
# Kurtosis:                       1.900   Cond. No.                     1.23e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.23e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1993:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     2.882
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0747
# Time:                        12:29:05   Log-Likelihood:                -106.25
# No. Observations:                  28   AIC:                             218.5
# Df Residuals:                      25   BIC:                             222.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -203.2960    120.822     -1.683      0.105    -452.134      45.542
# salary        32.0178     15.383      2.081      0.048       0.336      63.699
# salary       -19.1581     13.732     -1.395      0.175     -47.441       9.124
# ==============================================================================
# Omnibus:                        0.311   Durbin-Watson:                   1.603
# Prob(Omnibus):                  0.856   Jarque-Bera (JB):                0.344
# Skew:                           0.219   Prob(JB):                        0.842
# Kurtosis:                       2.679   Cond. No.                     1.25e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1994:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     1.861
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.176
# Time:                        12:29:05   Log-Likelihood:                -94.059
# No. Observations:                  28   AIC:                             194.1
# Df Residuals:                      25   BIC:                             198.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -111.6969     95.279     -1.172      0.252    -307.929      84.535
# salary         9.2848      8.976      1.034      0.311      -9.202      27.772
# salary         0.5941     11.984      0.050      0.961     -24.088      25.276
# ==============================================================================
# Omnibus:                        9.637   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                7.943
# Skew:                           1.159   Prob(JB):                       0.0188
# Kurtosis:                       4.200   Cond. No.                     1.53e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1995:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     3.833
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0353
# Time:                        12:29:05   Log-Likelihood:                -100.68
# No. Observations:                  28   AIC:                             207.4
# Df Residuals:                      25   BIC:                             211.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -91.3002     97.355     -0.938      0.357    -291.806     109.206
# salary        32.4395     12.446      2.606      0.015       6.807      58.072
# salary       -28.0466     14.648     -1.915      0.067     -58.215       2.122
# ==============================================================================
# Omnibus:                        0.194   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.907   Jarque-Bera (JB):                0.017
# Skew:                           0.047   Prob(JB):                        0.991
# Kurtosis:                       2.924   Cond. No.                     1.24e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1996:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     8.039
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):            0.00201
# Time:                        12:29:05   Log-Likelihood:                -96.720
# No. Observations:                  28   AIC:                             199.4
# Df Residuals:                      25   BIC:                             203.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -100.2808     89.961     -1.115      0.276    -285.559      84.998
# salary        30.8188      7.998      3.853      0.001      14.347      47.290
# salary       -24.8006     10.252     -2.419      0.023     -45.915      -3.686
# ==============================================================================
# Omnibus:                        0.989   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.610   Jarque-Bera (JB):                0.892
# Skew:                          -0.211   Prob(JB):                        0.640
# Kurtosis:                       2.234   Cond. No.                     1.32e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# For 1997:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     1.864
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.176
# Time:                        12:29:05   Log-Likelihood:                -100.62
# No. Observations:                  28   AIC:                             207.2
# Df Residuals:                      25   BIC:                             211.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -67.3657     76.980     -0.875      0.390    -225.908      91.177
# salary         6.3495     11.462      0.554      0.585     -17.258      29.957
# salary         2.6316     13.155      0.200      0.843     -24.462      29.725
# ==============================================================================
# Omnibus:                        3.429   Durbin-Watson:                   1.610
# Prob(Omnibus):                  0.180   Jarque-Bera (JB):                1.441
# Skew:                          -0.031   Prob(JB):                        0.486
# Kurtosis:                       1.890   Cond. No.                         988.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1998:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.374
# Method:                 Least Squares   F-statistic:                     9.654
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):           0.000687
# Time:                        12:29:05   Log-Likelihood:                -112.11
# No. Observations:                  30   AIC:                             230.2
# Df Residuals:                      27   BIC:                             234.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -277.2724     81.564     -3.399      0.002    -444.628    -109.916
# salary        31.1097     11.063      2.812      0.009       8.411      53.808
# salary       -13.0256     10.772     -1.209      0.237     -35.128       9.077
# ==============================================================================
# Omnibus:                        0.664   Durbin-Watson:                   2.593
# Prob(Omnibus):                  0.717   Jarque-Bera (JB):                0.427
# Skew:                           0.286   Prob(JB):                        0.808
# Kurtosis:                       2.878   Cond. No.                         947.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1999:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     6.371
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):            0.00542
# Time:                        12:29:05   Log-Likelihood:                -112.07
# No. Observations:                  30   AIC:                             230.1
# Df Residuals:                      27   BIC:                             234.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -182.7101     75.539     -2.419      0.023    -337.703     -27.717
# salary         8.8551     11.748      0.754      0.458     -15.250      32.960
# salary         7.4791     13.153      0.569      0.574     -19.510      34.468
# ==============================================================================
# Omnibus:                        6.298   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.043   Jarque-Bera (JB):                1.975
# Skew:                           0.102   Prob(JB):                        0.373
# Kurtosis:                       1.760   Cond. No.                         883.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2000:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     3.506
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0443
# Time:                        12:29:05   Log-Likelihood:                -107.63
# No. Observations:                  30   AIC:                             221.3
# Df Residuals:                      27   BIC:                             225.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -54.6789     66.891     -0.817      0.421    -191.927      82.569
# salary       -13.7739     11.574     -1.190      0.244     -37.522       9.974
# salary        26.0337     13.757      1.892      0.069      -2.194      54.261
# ==============================================================================
# Omnibus:                        2.314   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.314   Jarque-Bera (JB):                1.216
# Skew:                          -0.001   Prob(JB):                        0.544
# Kurtosis:                       2.014   Cond. No.                         915.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2001:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     2.161
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.135
# Time:                        12:29:05   Log-Likelihood:                -116.80
# No. Observations:                  30   AIC:                             239.6
# Df Residuals:                      27   BIC:                             243.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -37.3867    108.106     -0.346      0.732    -259.202     184.429
# salary        25.7605     13.538      1.903      0.068      -2.017      53.538
# salary       -23.2586     17.035     -1.365      0.183     -58.211      11.693
# ==============================================================================
# Omnibus:                        0.342   Durbin-Watson:                   2.219
# Prob(Omnibus):                  0.843   Jarque-Bera (JB):                0.272
# Skew:                           0.209   Prob(JB):                        0.873
# Kurtosis:                       2.793   Cond. No.                     1.10e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2002:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.183
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     3.014
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0658
# Time:                        12:29:05   Log-Likelihood:                -119.78
# No. Observations:                  30   AIC:                             245.6
# Df Residuals:                      27   BIC:                             249.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -216.3079    130.862     -1.653      0.110    -484.814      52.198
# salary        21.7543     14.520      1.498      0.146      -8.038      51.546
# salary        -6.3163     17.481     -0.361      0.721     -42.183      29.551
# ==============================================================================
# Omnibus:                        0.384   Durbin-Watson:                   2.153
# Prob(Omnibus):                  0.825   Jarque-Bera (JB):                0.535
# Skew:                           0.082   Prob(JB):                        0.765
# Kurtosis:                       2.367   Cond. No.                     1.21e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2003:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     3.555
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0426
# Time:                        12:29:05   Log-Likelihood:                -116.34
# No. Observations:                  30   AIC:                             238.7
# Df Residuals:                      27   BIC:                             242.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -144.8028    111.051     -1.304      0.203    -372.661      83.055
# salary        21.9995     12.161      1.809      0.082      -2.953      46.952
# salary       -11.3876     16.137     -0.706      0.486     -44.499      21.724
# ==============================================================================
# Omnibus:                        3.521   Durbin-Watson:                   2.314
# Prob(Omnibus):                  0.172   Jarque-Bera (JB):                2.515
# Skew:                          -0.706   Prob(JB):                        0.284
# Kurtosis:                       3.137   Cond. No.                     1.16e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.16e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2004:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     5.745
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):            0.00834
# Time:                        12:29:05   Log-Likelihood:                -114.93
# No. Observations:                  30   AIC:                             235.9
# Df Residuals:                      27   BIC:                             240.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -208.3829     89.893     -2.318      0.028    -392.829     -23.937
# salary        21.1477     11.218      1.885      0.070      -1.869      44.165
# salary        -6.0588     13.232     -0.458      0.651     -33.209      21.091
# ==============================================================================
# Omnibus:                        7.473   Durbin-Watson:                   2.673
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                5.838
# Skew:                          -1.015   Prob(JB):                       0.0540
# Kurtosis:                       3.741   Cond. No.                         979.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2005:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     5.833
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):            0.00784
# Time:                        12:29:05   Log-Likelihood:                -108.15
# No. Observations:                  30   AIC:                             222.3
# Df Residuals:                      27   BIC:                             226.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -171.9427     76.519     -2.247      0.033    -328.947     -14.938
# salary        21.3141      9.205      2.316      0.028       2.427      40.201
# salary        -8.7831      9.795     -0.897      0.378     -28.881      11.315
# ==============================================================================
# Omnibus:                        1.383   Durbin-Watson:                   2.670
# Prob(Omnibus):                  0.501   Jarque-Bera (JB):                0.951
# Skew:                           0.026   Prob(JB):                        0.621
# Kurtosis:                       2.129   Cond. No.                     1.05e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2006:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     5.830
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):            0.00786
# Time:                        12:29:05   Log-Likelihood:                -106.00
# No. Observations:                  30   AIC:                             218.0
# Df Residuals:                      27   BIC:                             222.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -112.2695     64.317     -1.746      0.092    -244.237      19.697
# salary        -3.1228     10.069     -0.310      0.759     -23.783      17.537
# salary        16.6669     11.183      1.490      0.148      -6.279      39.613
# ==============================================================================
# Omnibus:                        2.241   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.326   Jarque-Bera (JB):                1.205
# Skew:                           0.050   Prob(JB):                        0.547
# Kurtosis:                       2.023   Cond. No.                         950.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2007:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     4.748
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0171
# Time:                        12:29:05   Log-Likelihood:                -104.42
# No. Observations:                  30   AIC:                             214.8
# Df Residuals:                      27   BIC:                             219.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -90.2266     65.568     -1.376      0.180    -224.762      44.309
# salary         1.6454     11.407      0.144      0.886     -21.761      25.051
# salary         9.4424     11.884      0.795      0.434     -14.941      33.826
# ==============================================================================
# Omnibus:                        0.431   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.806   Jarque-Bera (JB):                0.571
# Skew:                           0.212   Prob(JB):                        0.752
# Kurtosis:                       2.473   Cond. No.                     1.03e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# For 2008:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     2.138
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.137
# Time:                        12:29:05   Log-Likelihood:                -112.02
# No. Observations:                  30   AIC:                             230.0
# Df Residuals:                      27   BIC:                             234.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -116.2593     96.729     -1.202      0.240    -314.731      82.212
# salary        25.9366     14.360      1.806      0.082      -3.527      55.400
# salary       -18.2979     13.008     -1.407      0.171     -44.987       8.391
# ==============================================================================
# Omnibus:                        1.918   Durbin-Watson:                   1.467
# Prob(Omnibus):                  0.383   Jarque-Bera (JB):                1.483
# Skew:                          -0.538   Prob(JB):                        0.476
# Kurtosis:                       2.828   Cond. No.                     1.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2009:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     4.517
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0203
# Time:                        12:29:05   Log-Likelihood:                -110.83
# No. Observations:                  30   AIC:                             227.7
# Df Residuals:                      27   BIC:                             231.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -153.6027     98.125     -1.565      0.129    -354.939      47.733
# salary        -1.1569     13.394     -0.086      0.932     -28.638      26.324
# salary        16.8759     13.423      1.257      0.219     -10.666      44.418
# ==============================================================================
# Omnibus:                        1.715   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.424   Jarque-Bera (JB):                1.059
# Skew:                           0.047   Prob(JB):                        0.589
# Kurtosis:                       2.084   Cond. No.                     1.25e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2010:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     2.151
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.136
# Time:                        12:29:05   Log-Likelihood:                -111.79
# No. Observations:                  30   AIC:                             229.6
# Df Residuals:                      27   BIC:                             233.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -94.9833     90.734     -1.047      0.304    -281.154      91.188
# salary         5.4742     15.834      0.346      0.732     -27.015      37.963
# salary         5.0246     16.859      0.298      0.768     -29.567      39.616
# ==============================================================================
# Omnibus:                        2.255   Durbin-Watson:                   2.673
# Prob(Omnibus):                  0.324   Jarque-Bera (JB):                1.244
# Skew:                          -0.116   Prob(JB):                        0.537
# Kurtosis:                       2.030   Cond. No.                     1.12e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2011:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     3.572
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0420
# Time:                        12:29:05   Log-Likelihood:                -111.59
# No. Observations:                  30   AIC:                             229.2
# Df Residuals:                      27   BIC:                             233.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -159.1853     91.479     -1.740      0.093    -346.885      28.515
# salary        28.4659     12.273      2.319      0.028       3.284      53.648
# salary       -18.5064     10.966     -1.688      0.103     -41.006       3.993
# ==============================================================================
# Omnibus:                        2.395   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.302   Jarque-Bera (JB):                1.239
# Skew:                           0.028   Prob(JB):                        0.538
# Kurtosis:                       2.006   Cond. No.                     1.14e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.14e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2012:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     2.869
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0742
# Time:                        12:29:05   Log-Likelihood:                -113.55
# No. Observations:                  30   AIC:                             233.1
# Df Residuals:                      27   BIC:                             237.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -91.0857    114.121     -0.798      0.432    -325.242     143.070
# salary        29.8822     12.479      2.395      0.024       4.278      55.486
# salary       -24.6884     11.651     -2.119      0.043     -48.595      -0.782
# ==============================================================================
# Omnibus:                        3.844   Durbin-Watson:                   2.487
# Prob(Omnibus):                  0.146   Jarque-Bera (JB):                1.634
# Skew:                          -0.155   Prob(JB):                        0.442
# Kurtosis:                       1.899   Cond. No.                     1.33e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2013:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     3.853
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):             0.0337
# Time:                        12:29:05   Log-Likelihood:                -113.47
# No. Observations:                  30   AIC:                             232.9
# Df Residuals:                      27   BIC:                             237.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -110.5761     73.235     -1.510      0.143    -260.841      39.689
# salary        22.8589     11.323      2.019      0.054      -0.375      46.092
# salary       -14.9387     12.219     -1.223      0.232     -40.010      10.133
# ==============================================================================
# Omnibus:                        1.643   Durbin-Watson:                   2.268
# Prob(Omnibus):                  0.440   Jarque-Bera (JB):                1.038
# Skew:                           0.049   Prob(JB):                        0.595
# Kurtosis:                       2.094   Cond. No.                         856.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2014:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     1.642
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.212
# Time:                        12:29:05   Log-Likelihood:                -108.19
# No. Observations:                  30   AIC:                             222.4
# Df Residuals:                      27   BIC:                             226.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -62.8989     79.596     -0.790      0.436    -226.216     100.419
# salary         7.4663      8.549      0.873      0.390     -10.075      25.008
# salary         0.4234      9.351      0.045      0.964     -18.764      19.611
# ==============================================================================
# Omnibus:                        1.541   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.463   Jarque-Bera (JB):                1.119
# Skew:                          -0.206   Prob(JB):                        0.572
# Kurtosis:                       2.149   Cond. No.                     1.11e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2015:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     1.812
# Date:                Tue, 14 Nov 2017   Prob (F-statistic):              0.183
# Time:                        12:29:05   Log-Likelihood:                -110.58
# No. Observations:                  30   AIC:                             227.2
# Df Residuals:                      27   BIC:                             231.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -79.6175    105.045     -0.758      0.455    -295.152     135.917
# salary        21.7614     11.963      1.819      0.080      -2.785      46.308
# salary       -15.7441     11.718     -1.344      0.190     -39.787       8.299
# ==============================================================================
# Omnibus:                        0.979   Durbin-Watson:                   2.236
# Prob(Omnibus):                  0.613   Jarque-Bera (JB):                0.922
# Skew:                           0.235   Prob(JB):                        0.631
# Kurtosis:                       2.281   Cond. No.                     1.37e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y, X1, X2 = salary_dist_year(2012)
X = pd.concat([X1,X2],axis=1)
plt.scatter(np.log(X1),np.log(X2))

# %% [markdown]
# ### Salary by Position

# %%
appearances['str_pos'] = appearances[['g_p', 'g_c', 'g_1b', 'g_2b', 'g_3b', 'g_ss',
                                'g_lf', 'g_cf', 'g_rf', 'g_dh']].idxmax(axis=1).str.replace('g_', '')

# %%
appearances[appearances.year > 1984].str_pos.value_counts()
# Out:
# p     18971
# c      3172
# lf     2857
# 2b     2308
# rf     2250
# 3b     2230
# 1b     2171
# ss     1999
# cf     1978
# dh      810
# Name: str_pos, dtype: int64

# %% [markdown]
# #### Do starters play more seasons than non-starters?
#
# A friend suggested there may be a relationship between number of games played per year and how long a player remains in the MLB. The scatterplot below shows somewhat of a U-shaped relationship between the two. The cluster in the bottom-left are a majority of players who rarely start games and only play in the MLB for a few years.

# %%
app_salary = appearances.merge(salary)

# %%
seasons = app_salary.groupby('player_id').size()
gs = app_salary.groupby('player_id')['gs'].mean()
g = app_salary.groupby('player_id')['g_all'].mean()
age = app_salary.groupby('player_id')['age'].max()

# %%
plt.scatter(gs, seasons, alpha=0.2)

# %% [markdown]
# #### Salary by position

# %%
app_salary[app_salary.year == 2015].groupby('str_pos')['salary'].median() / 1000000
# Out:
# str_pos
# 1b    3.10000
# 2b    1.07500
# 3b    2.52500
# c     1.03750
# cf    1.65000
# dh    6.58300
# lf    2.10000
# p     1.48000
# rf    4.10000
# ss    1.44375
# Name: salary, dtype: float64

# %%
positions = {}
for pos in ['p', 'c', '1b', '2b', '3b', 'ss', 'lf', 'cf', 'rf', 'dh']:
    positions[(pos.replace('', ''))] = app_salary[app_salary.str_pos == pos]

# %%
def distribution_salary_pos(year, pos, title):
    pos_df = app_salary[app_salary.str_pos == pos]
    np.log(pos_df[(pos_df.year == year)].groupby('player_id')['salary'].mean()).plot(
        kind='hist', bins=10, title=f'Log salaries for {title} in {year}', alpha=0.4)

# %%
distribution_salary_pos(2015, '2b', 'infielders')
distribution_salary_pos(2015, '1b', 'infielders')
distribution_salary_pos(2015, 'dh', 'infielders')

# %%
distribution_salary_pos(2015, 'lf', 'outfielders')
distribution_salary_pos(2015, 'cf', 'outfielders')
distribution_salary_pos(2015, 'rf', 'outfielders')

# %%
distribution_salary_pos(2015, 'p', 'pitchers')

# %% [markdown]
# ### Player Features

# %%
features = app_salary

# %%
features = features.merge(player)

# %%
team_age = features[features.year == 2012].groupby('team_id')['age'].mean()
team_salary = features[features.year == 2012].groupby('team_id')['salary'].sum()
plt.scatter(team_age, np.log(team_salary))

# %%
plt.scatter(features[features.year == 2012].age, np.log(features[features.year == 2012].salary), alpha=0.2)

# %%
salary_pitch = salary.merge(pitching)

# %%
salary_bat = salary.merge(batting).set_index('player_id').drop(salary_pitch.player_id).reset_index()

# %%
def bat_pitch_salary(year):
    bat_year = salary_bat[salary_bat.year == year]
    pitch_year = salary_pitch[salary_pitch.year == year]
    team_year = team[team.year == year]
    wins = team_year.groupby('team_id')['w'].median()
    team_bat = bat_year.groupby(['team_id'])['salary'].sum() / bat_year.groupby(['team_id']).size()
    team_pitch = pitch_year.groupby(['team_id'])['salary'].sum() / pitch_year.groupby(['team_id']).size()
    return wins, (team_bat / (team_pitch + team_bat))

# %%
def bat_pitch(year):
    bat_year = salary_bat[salary_bat.year == year]
    pitch_year = salary_pitch[salary_pitch.year == year]
    team_year = team[team.year == year]
    wins = team_year.groupby('team_id')['w'].median()
    team_bat = bat_year.groupby(['team_id']).size()
    team_pitch = pitch_year.groupby(['team_id']).size()
    return wins, (team_bat / (team_pitch + team_bat))

# %%
for year in range(1985, 2016):
    y, X = bat_pitch_salary(year)
    X = np.log(X)
    X = sm.add_constant(X)
    results = smf.OLS(y, X).fit()
    print(f'\nFor {year}:\n{results.summary()}')
# Out:
# For 1985:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.039
# Method:                 Least Squares   F-statistic:                   0.06550
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.800
# Time:                        15:55:06   Log-Likelihood:                -102.17
# No. Observations:                  26   AIC:                             208.3
# Df Residuals:                      24   BIC:                             210.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         77.5713     12.893      6.016      0.000      50.961     104.182
# 0             -4.9064     19.172     -0.256      0.800     -44.475      34.662
# ==============================================================================
# Omnibus:                        1.021   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.600   Jarque-Bera (JB):                0.877
# Skew:                          -0.194   Prob(JB):                        0.645
# Kurtosis:                       2.188   Cond. No.                         11.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1986:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     2.594
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.120
# Time:                        15:55:06   Log-Likelihood:                -95.601
# No. Observations:                  26   AIC:                             195.2
# Df Residuals:                      24   BIC:                             197.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         92.1531      7.287     12.646      0.000      77.113     107.193
# 0             17.5505     10.897      1.611      0.120      -4.941      40.042
# ==============================================================================
# Omnibus:                        2.774   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.250   Jarque-Bera (JB):                1.882
# Skew:                           0.659   Prob(JB):                        0.390
# Kurtosis:                       3.038   Cond. No.                         7.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1987:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.024
# Method:                 Least Squares   F-statistic:                    0.4050
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.531
# Time:                        15:55:06   Log-Likelihood:                -95.625
# No. Observations:                  26   AIC:                             195.3
# Df Residuals:                      24   BIC:                             197.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         83.7452      4.791     17.480      0.000      73.857      93.633
# 0              3.9235      6.165      0.636      0.531      -8.801      16.648
# ==============================================================================
# Omnibus:                        0.333   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.847   Jarque-Bera (JB):                0.435
# Skew:                          -0.230   Prob(JB):                        0.805
# Kurtosis:                       2.563   Cond. No.                         4.85
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1988:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     2.265
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.145
# Time:                        15:55:06   Log-Likelihood:                -99.881
# No. Observations:                  26   AIC:                             203.8
# Df Residuals:                      24   BIC:                             206.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         67.3691      9.146      7.366      0.000      48.492      86.246
# 0            -20.3041     13.490     -1.505      0.145     -48.147       7.539
# ==============================================================================
# Omnibus:                        1.503   Durbin-Watson:                   1.324
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                0.683
# Skew:                          -0.384   Prob(JB):                        0.711
# Kurtosis:                       3.204   Cond. No.                         8.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1989:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     3.755
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0645
# Time:                        15:55:06   Log-Likelihood:                -94.332
# No. Observations:                  26   AIC:                             192.7
# Df Residuals:                      24   BIC:                             195.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         65.5243      8.142      8.048      0.000      48.720      82.329
# 0            -23.7715     12.268     -1.938      0.065     -49.091       1.548
# ==============================================================================
# Omnibus:                        1.024   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.599   Jarque-Bera (JB):                0.971
# Skew:                          -0.306   Prob(JB):                        0.615
# Kurtosis:                       2.278   Cond. No.                         9.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1990:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     3.642
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0684
# Time:                        15:55:06   Log-Likelihood:                -91.877
# No. Observations:                  26   AIC:                             187.8
# Df Residuals:                      24   BIC:                             190.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.4382      5.768     12.212      0.000      58.534      82.342
# 0            -16.8837      8.847     -1.908      0.068     -35.143       1.376
# ==============================================================================
# Omnibus:                        1.652   Durbin-Watson:                   2.411
# Prob(Omnibus):                  0.438   Jarque-Bera (JB):                1.107
# Skew:                           0.504   Prob(JB):                        0.575
# Kurtosis:                       2.913   Cond. No.                         7.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1991:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     4.569
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0429
# Time:                        15:55:06   Log-Likelihood:                -93.223
# No. Observations:                  26   AIC:                             190.4
# Df Residuals:                      24   BIC:                             193.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         94.5650      6.626     14.271      0.000      80.889     108.241
# 0             20.0152      9.364      2.137      0.043       0.689      39.341
# ==============================================================================
# Omnibus:                        0.821   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.101
# Skew:                           0.012   Prob(JB):                        0.951
# Kurtosis:                       3.304   Cond. No.                         7.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1992:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                   0.04867
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.827
# Time:                        15:55:06   Log-Likelihood:                -96.783
# No. Observations:                  26   AIC:                             197.6
# Df Residuals:                      24   BIC:                             200.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         83.0129      9.350      8.878      0.000      63.714     102.311
# 0              2.9195     13.234      0.221      0.827     -24.394      30.233
# ==============================================================================
# Omnibus:                        2.142   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.156
# Skew:                           0.093   Prob(JB):                        0.561
# Kurtosis:                       1.984   Cond. No.                         9.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1993:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                    0.2327
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.634
# Time:                        15:55:06   Log-Likelihood:                -109.03
# No. Observations:                  28   AIC:                             222.1
# Df Residuals:                      26   BIC:                             224.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         76.5826      9.448      8.105      0.000      57.161      96.004
# 0             -6.4519     13.373     -0.482      0.634     -33.941      21.037
# ==============================================================================
# Omnibus:                        0.662   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.718   Jarque-Bera (JB):                0.667
# Skew:                           0.026   Prob(JB):                        0.716
# Kurtosis:                       2.245   Cond. No.                         8.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1994:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.033
# Method:                 Least Squares   F-statistic:                    0.1329
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.718
# Time:                        15:55:06   Log-Likelihood:                -95.930
# No. Observations:                  28   AIC:                             195.9
# Df Residuals:                      26   BIC:                             198.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         55.5021      4.639     11.965      0.000      45.967      65.037
# 0             -2.4067      6.602     -0.365      0.718     -15.978      11.164
# ==============================================================================
# Omnibus:                        3.001   Durbin-Watson:                   1.612
# Prob(Omnibus):                  0.223   Jarque-Bera (JB):                2.533
# Skew:                           0.638   Prob(JB):                        0.282
# Kurtosis:                       2.263   Cond. No.                         6.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1995:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     1.500
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.232
# Time:                        15:55:06   Log-Likelihood:                -103.64
# No. Observations:                  28   AIC:                             211.3
# Df Residuals:                      26   BIC:                             213.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         65.5014      5.643     11.608      0.000      53.903      77.100
# 0            -10.9278      8.921     -1.225      0.232     -29.265       7.410
# ==============================================================================
# Omnibus:                        4.743   Durbin-Watson:                   1.492
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                2.999
# Skew:                           0.674   Prob(JB):                        0.223
# Kurtosis:                       3.867   Cond. No.                         6.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1996:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     4.362
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0467
# Time:                        15:55:06   Log-Likelihood:                -101.50
# No. Observations:                  28   AIC:                             207.0
# Df Residuals:                      26   BIC:                             209.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         72.1260      4.576     15.763      0.000      62.721      81.531
# 0            -15.7683      7.550     -2.088      0.047     -31.288      -0.249
# ==============================================================================
# Omnibus:                        1.899   Durbin-Watson:                   2.306
# Prob(Omnibus):                  0.387   Jarque-Bera (JB):                1.412
# Skew:                          -0.545   Prob(JB):                        0.494
# Kurtosis:                       2.849   Cond. No.                         5.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1997:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     2.851
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.103
# Time:                        15:55:06   Log-Likelihood:                -101.11
# No. Observations:                  28   AIC:                             206.2
# Df Residuals:                      26   BIC:                             208.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         71.1304      6.063     11.733      0.000      58.668      83.592
# 0            -18.0415     10.684     -1.689      0.103     -40.004       3.921
# ==============================================================================
# Omnibus:                        1.458   Durbin-Watson:                   1.664
# Prob(Omnibus):                  0.482   Jarque-Bera (JB):                0.990
# Skew:                           0.107   Prob(JB):                        0.609
# Kurtosis:                       2.104   Cond. No.                         7.92
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1998:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9597
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.336
# Time:                        15:55:06   Log-Likelihood:                -119.70
# No. Observations:                  30   AIC:                             243.4
# Df Residuals:                      28   BIC:                             246.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         74.4046      7.172     10.374      0.000      59.713      89.096
# 0            -11.0385     11.268     -0.980      0.336     -34.120      12.043
# ==============================================================================
# Omnibus:                        1.319   Durbin-Watson:                   2.520
# Prob(Omnibus):                  0.517   Jarque-Bera (JB):                1.033
# Skew:                           0.442   Prob(JB):                        0.597
# Kurtosis:                       2.790   Cond. No.                         6.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1999:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                    0.2016
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.657
# Time:                        15:55:06   Log-Likelihood:                -117.76
# No. Observations:                  30   AIC:                             239.5
# Df Residuals:                      28   BIC:                             242.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         77.1944      8.572      9.005      0.000      59.635      94.754
# 0             -5.5686     12.402     -0.449      0.657     -30.974      19.837
# ==============================================================================
# Omnibus:                        6.822   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                2.232
# Skew:                           0.237   Prob(JB):                        0.328
# Kurtosis:                       1.750   Cond. No.                         7.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2000:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                    0.5052
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.483
# Time:                        15:55:06   Log-Likelihood:                -110.83
# No. Observations:                  30   AIC:                             225.7
# Df Residuals:                      28   BIC:                             228.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         75.8789      7.345     10.331      0.000      60.833      90.924
# 0             -8.0589     11.338     -0.711      0.483     -31.284      15.166
# ==============================================================================
# Omnibus:                        4.168   Durbin-Watson:                   1.655
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                1.608
# Skew:                          -0.028   Prob(JB):                        0.448
# Kurtosis:                       1.867   Cond. No.                         8.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2001:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     4.558
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0417
# Time:                        15:55:07   Log-Likelihood:                -116.76
# No. Observations:                  30   AIC:                             237.5
# Df Residuals:                      28   BIC:                             240.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         66.3063      7.208      9.198      0.000      51.540      81.072
# 0            -24.1078     11.292     -2.135      0.042     -47.238      -0.977
# ==============================================================================
# Omnibus:                        2.445   Durbin-Watson:                   2.190
# Prob(Omnibus):                  0.295   Jarque-Bera (JB):                1.674
# Skew:                           0.578   Prob(JB):                        0.433
# Kurtosis:                       3.046   Cond. No.                         6.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2002:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.204
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     7.192
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0121
# Time:                        15:55:07   Log-Likelihood:                -119.37
# No. Observations:                  30   AIC:                             242.7
# Df Residuals:                      28   BIC:                             245.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         65.0187      6.384     10.185      0.000      51.942      78.095
# 0            -27.2320     10.154     -2.682      0.012     -48.032      -6.432
# ==============================================================================
# Omnibus:                        0.840   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.657   Jarque-Bera (JB):                0.820
# Skew:                          -0.189   Prob(JB):                        0.664
# Kurtosis:                       2.283   Cond. No.                         5.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2003:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     3.237
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0828
# Time:                        15:55:07   Log-Likelihood:                -118.20
# No. Observations:                  30   AIC:                             240.4
# Df Residuals:                      28   BIC:                             243.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.0778      6.493     10.793      0.000      56.778      83.377
# 0            -20.7769     11.548     -1.799      0.083     -44.431       2.877
# ==============================================================================
# Omnibus:                        0.945   Durbin-Watson:                   2.176
# Prob(Omnibus):                  0.623   Jarque-Bera (JB):                0.707
# Skew:                          -0.365   Prob(JB):                        0.702
# Kurtosis:                       2.819   Cond. No.                         6.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2004:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     2.906
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0993
# Time:                        15:55:07   Log-Likelihood:                -118.76
# No. Observations:                  30   AIC:                             241.5
# Df Residuals:                      28   BIC:                             244.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         68.9980      7.400      9.324      0.000      53.840      84.156
# 0            -22.1920     13.018     -1.705      0.099     -48.858       4.474
# ==============================================================================
# Omnibus:                        0.851   Durbin-Watson:                   2.867
# Prob(Omnibus):                  0.653   Jarque-Bera (JB):                0.731
# Skew:                          -0.356   Prob(JB):                        0.694
# Kurtosis:                       2.722   Cond. No.                         7.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2005:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     4.062
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0535
# Time:                        15:55:07   Log-Likelihood:                -111.51
# No. Observations:                  30   AIC:                             227.0
# Df Residuals:                      28   BIC:                             229.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         69.3244      6.091     11.382      0.000      56.848      81.800
# 0            -19.8574      9.852     -2.016      0.054     -40.039       0.324
# ==============================================================================
# Omnibus:                        0.301   Durbin-Watson:                   2.607
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.482
# Skew:                           0.120   Prob(JB):                        0.786
# Kurtosis:                       2.428   Cond. No.                         7.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2006:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     2.476
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.127
# Time:                        15:55:07   Log-Likelihood:                -110.12
# No. Observations:                  30   AIC:                             224.2
# Df Residuals:                      28   BIC:                             227.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.7379      6.744     10.489      0.000      56.923      84.552
# 0            -17.0442     10.832     -1.574      0.127     -39.232       5.144
# ==============================================================================
# Omnibus:                        0.866   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.649   Jarque-Bera (JB):                0.787
# Skew:                           0.110   Prob(JB):                        0.675
# Kurtosis:                       2.238   Cond. No.                         8.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2007:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.230
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.277
# Time:                        15:55:07   Log-Likelihood:                -108.30
# No. Observations:                  30   AIC:                             220.6
# Df Residuals:                      28   BIC:                             223.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         74.5262      6.105     12.207      0.000      62.020      87.032
# 0            -10.5960      9.553     -1.109      0.277     -30.165       8.973
# ==============================================================================
# Omnibus:                        5.044   Durbin-Watson:                   2.412
# Prob(Omnibus):                  0.080   Jarque-Bera (JB):                1.850
# Skew:                           0.159   Prob(JB):                        0.397
# Kurtosis:                       1.826   Cond. No.                         7.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2008:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.030
# Method:                 Least Squares   F-statistic:                    0.1657
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.687
# Time:                        15:55:07   Log-Likelihood:                -114.14
# No. Observations:                  30   AIC:                             232.3
# Df Residuals:                      28   BIC:                             235.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         78.4809      6.366     12.329      0.000      65.441      91.520
# 0             -4.0063      9.843     -0.407      0.687     -24.168      16.156
# ==============================================================================
# Omnibus:                        1.273   Durbin-Watson:                   1.516
# Prob(Omnibus):                  0.529   Jarque-Bera (JB):                0.985
# Skew:                          -0.167   Prob(JB):                        0.611
# Kurtosis:                       2.178   Cond. No.                         6.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2009:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                  0.007516
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.932
# Time:                        15:55:07   Log-Likelihood:                -115.16
# No. Observations:                  30   AIC:                             234.3
# Df Residuals:                      28   BIC:                             237.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.3924      7.323     10.977      0.000      65.391      95.394
# 0             -1.0029     11.568     -0.087      0.932     -24.700      22.694
# ==============================================================================
# Omnibus:                        1.317   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.518   Jarque-Bera (JB):                1.014
# Skew:                          -0.182   Prob(JB):                        0.602
# Kurtosis:                       2.176   Cond. No.                         7.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2010:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.023
# Method:                 Least Squares   F-statistic:                    0.3385
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.565
# Time:                        15:55:07   Log-Likelihood:                -113.83
# No. Observations:                  30   AIC:                             231.7
# Df Residuals:                      28   BIC:                             234.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         85.3958      7.824     10.914      0.000      69.369     101.423
# 0              6.9334     11.917      0.582      0.565     -17.478      31.344
# ==============================================================================
# Omnibus:                        2.346   Durbin-Watson:                   2.675
# Prob(Omnibus):                  0.309   Jarque-Bera (JB):                1.809
# Skew:                          -0.438   Prob(JB):                        0.405
# Kurtosis:                       2.176   Cond. No.                         8.27
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2011:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.033
# Method:                 Least Squares   F-statistic:                   0.06958
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.794
# Time:                        15:55:07   Log-Likelihood:                -115.07
# No. Observations:                  30   AIC:                             234.1
# Df Residuals:                      28   BIC:                             236.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         82.8848      7.574     10.943      0.000      67.370      98.399
# 0              3.3646     12.756      0.264      0.794     -22.764      29.494
# ==============================================================================
# Omnibus:                        0.604   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.739   Jarque-Bera (JB):                0.653
# Skew:                          -0.072   Prob(JB):                        0.721
# Kurtosis:                       2.291   Cond. No.                         8.02
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2012:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.204
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.282
# Time:                        15:55:07   Log-Likelihood:                -115.81
# No. Observations:                  30   AIC:                             235.6
# Df Residuals:                      28   BIC:                             238.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         88.1197      6.842     12.879      0.000      74.104     102.135
# 0             11.0736     10.092      1.097      0.282      -9.599      31.746
# ==============================================================================
# Omnibus:                        2.085   Durbin-Watson:                   2.466
# Prob(Omnibus):                  0.353   Jarque-Bera (JB):                1.558
# Skew:                          -0.367   Prob(JB):                        0.459
# Kurtosis:                       2.159   Cond. No.                         6.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2013:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     6.976
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):             0.0134
# Time:                        15:55:07   Log-Likelihood:                -113.90
# No. Observations:                  30   AIC:                             231.8
# Df Residuals:                      28   BIC:                             234.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         98.5217      6.928     14.222      0.000      84.331     112.712
# 0             27.2654     10.323      2.641      0.013       6.120      48.411
# ==============================================================================
# Omnibus:                        1.845   Durbin-Watson:                   2.466
# Prob(Omnibus):                  0.397   Jarque-Bera (JB):                1.600
# Skew:                          -0.537   Prob(JB):                        0.449
# Kurtosis:                       2.647   Cond. No.                         7.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2014:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.105
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.302
# Time:                        15:55:07   Log-Likelihood:                -109.33
# No. Observations:                  30   AIC:                             222.7
# Df Residuals:                      28   BIC:                             225.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         87.0547      6.020     14.460      0.000      74.723      99.387
# 0              9.8989      9.418      1.051      0.302      -9.393      29.191
# ==============================================================================
# Omnibus:                        1.432   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.489   Jarque-Bera (JB):                0.973
# Skew:                          -0.051   Prob(JB):                        0.615
# Kurtosis:                       2.124   Cond. No.                         7.45
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2015:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                    0.3683
# Date:                Thu, 16 Nov 2017   Prob (F-statistic):              0.549
# Time:                        15:55:07   Log-Likelihood:                -112.27
# No. Observations:                  30   AIC:                             228.5
# Df Residuals:                      28   BIC:                             231.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         76.9900      6.831     11.271      0.000      62.997      90.983
# 0             -6.7331     11.095     -0.607      0.549     -29.460      15.994
# ==============================================================================
# Omnibus:                        2.625   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.269   Jarque-Bera (JB):                1.297
# Skew:                           0.039   Prob(JB):                        0.523
# Kurtosis:                       1.985   Cond. No.                         7.80
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y, X = bat_pitch_salary(1996)
plt.scatter(X,y)

# %%
for year in range(1985,2011):
    y, X = bat_pitch_salary(year)
    plt.scatter(X,y,alpha=0.5)

# %%
for year in range(2012,2016):
    y, X = bat_pitch_salary(year)
    plt.scatter(X,y,alpha=0.5)

# %%
salary_bat[salary_bat.year == 2015].groupby(['team_id'])['salary'].sum() / 1000000
# Out:
# team_id
# ARI     36.775500
# ATL     45.537500
# BAL     50.690833
# BOS    108.834900
# CHA     33.790000
# CHN     43.580310
# CIN     59.605000
# CLE     44.321166
# COL     57.622600
# DET     79.399750
# HOU     38.078100
# KCA     55.532025
# LAA     59.391915
# LAN    114.088500
# MIA     25.671500
# MIL     55.849000
# MIN     51.497500
# NYA    133.914557
# NYN     53.608728
# OAK     35.473500
# PHI     60.614000
# PIT     40.813333
# SDN     62.880200
# SEA     70.843500
# SFN     69.806500
# SLN     69.186000
# TBA     43.488066
# TEX     99.482889
# TOR     69.975600
# WAS     74.079172
# Name: salary, dtype: float64

# %%
salary_pitch[salary_pitch.year == 2015].groupby(['team_id'])['salary'].sum() / 1000000
# Out:
# team_id
# ARI     20.183500
# ATL     24.943750
# BAL     50.254000
# BOS     60.997500
# CHA     78.583700
# CHN     72.299000
# CIN     50.967286
# CLE     28.342600
# COL     24.066000
# DET     92.365000
# HOU     33.664200
# KCA     56.575000
# LAA     59.626000
# LAN    101.703500
# MIA     39.635000
# MIL     44.176000
# MIN     56.257500
# NYA     78.837400
# NYN     34.140075
# OAK     40.230001
# PHI     48.579000
# PIT     45.029166
# SDN     55.561100
# SEA     51.365200
# SFN     94.895000
# SLN     50.055500
# TBA     19.333167
# TEX     41.309900
# TOR     43.016800
# WAS     81.508300
# Name: salary, dtype: float64
