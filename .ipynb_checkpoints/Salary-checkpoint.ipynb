# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
player = pd.read_csv('data/baseball/player.csv')
salary = pd.read_csv('data/baseball/salary.csv')
appearances = pd.read_csv('data/baseball/appearances.csv')
batting = pd.read_csv('data/baseball/batting.csv')
fielding = pd.read_csv('data/baseball/fielding.csv')
team = pd.read_csv('data/baseball/team.csv')
pitching = pd.read_csv('data/baseball/pitching.csv')

# %% [markdown]
# For the project, we are looking at the importance of salary for building a baseball team.

# %% [markdown]
# ### Distributions
#
# #### By year (individual players)

# %%
np.log(salary.groupby('player_id')['salary'].mean()).plot(kind='hist', bins=12, title='Log of mean salaries')

# %%
def distribution_salary(year):
    np.log(salary[(salary.year == year)].salary).plot(kind='hist', bins=20, title=f'Log salaries in {year}')

# %%
distribution_salary(2005)

# %%
distribution_salary(1995)

# %%
distribution_salary(1985)

# %% [markdown]
# #### By year (team totals)

# %%
np.log(salary[(salary.year == 1985)].groupby('team_id')['salary'].sum()).plot(
    kind='hist', bins=8, title='Log team salaries 1985')

# %%
np.log(salary[(salary.year == 1995)].groupby('team_id')['salary'].sum()).plot(
    kind='hist', bins=8, title='Log team salaries 1995')

# %%
np.log(salary[(salary.year == 2005)].groupby('team_id')['salary'].sum()).plot(
    kind='hist', bins=8, title='Log team salaries 2005')

# %%
np.log(salary[(salary.year == 2015)].groupby('team_id')['salary'].sum()).plot(
    kind='hist', bins=8, title='Log team salaries 2015')

# %% [markdown]
# ### Scatterplots and Regressions
#
# #### Do Higher Team Salaries Translate to More Wins?

# %%
team_salary = team.merge(salary)

# %%
def wins_salary_graph(year):
    team_salary_year = team_salary[team_salary.year == year]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_total = team_salary_year.groupby('team_id')['salary'].sum()
    plt.scatter(np.log(salary_total), wins)
    plt.ylabel("Team wins")
    plt.xlabel("Log team salary")
    plt.title(f"How does salary impact wins?\n{year} season")

# %%
wins_salary_graph(2015)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
def salary_year(year):
    team_salary_year = team_salary[team_salary.year == year]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_total = team_salary_year.groupby('team_id')['salary'].sum()
    return wins.values.reshape(-1, 1), salary_total.values.reshape(-1, 1)

# %%
for year in range(1985, 2016):
    X, y = salary_year(year)
    lr.fit(X, y)
    print(f'For {year}, score is {lr.score(X, y)} and coef is {int(lr.coef_[0][0])}')
# Out:
# For 1985, score is 0.11700174241556749 and coef is 67220
# For 1986, score is 0.044234049535041176 and coef is 65283
# For 1987, score is 0.0031557496199029478 and coef is -21959
# For 1988, score is 0.02632758863617024 and coef is 45677
# For 1989, score is 0.11595839440227573 and coef is 121658
# For 1990, score is 2.751561907210487e-06 and coef is 689
# For 1991, score is 0.054500099342046804 and coef is 165738
# For 1992, score is 0.0010680856213920453 and coef is 29268
# For 1993, score is 0.12435582553474234 and coef is 267889
# For 1994, score is 0.15891061890259595 and coef is 447471
# For 1995, score is 0.10668704480061586 and coef is 300685
# For 1996, score is 0.30248052850612994 and coef is 588302
# For 1997, score is 0.19360255183606667 and coef is 598195
# For 1998, score is 0.4329724164504356 and coef is 748071
# For 1999, score is 0.31802778257883224 and coef is 926457
# For 2000, score is 0.10962041048066262 and coef is 710065
# For 2001, score is 0.10281516676377 and coef is 609119
# For 2002, score is 0.19573149887150354 and coef is 740456
# For 2003, score is 0.17531263283073684 and coef is 877493
# For 2004, score is 0.2926970193805374 and coef is 1310898
# For 2005, score is 0.24114929963704712 and coef is 1549005
# For 2006, score is 0.2875919268215591 and coef is 1715866
# For 2007, score is 0.24113529076428686 and coef is 1791506
# For 2008, score is 0.1069115641293823 and coef is 1114975
# For 2009, score is 0.22687146711511907 and coef is 1410277
# For 2010, score is 0.13606465871722817 and coef is 1277587
# For 2011, score is 0.16744702682086332 and coef is 1462981
# For 2012, score is 0.036121541624453246 and coef is 586356
# For 2013, score is 0.08974784599127916 and coef is 1193734
# For 2014, score is 0.10251856209507947 and coef is 1421051
# For 2015, score is 0.05671767870483635 and coef is 925216

# %%
wins_salary_graph(1998)

# %%
wins_salary_graph(1987)

# %%
team_salary_year = team_salary[team_salary.year == 2015]
team_salary_year.describe()
# Out:
#          year        rank           g       ghome           w           l  \
# count   816.0  816.000000  816.000000  816.000000  816.000000  816.000000
# mean   2015.0    2.993873  161.933824   80.968137   81.136029   80.797794
# std       0.0    1.412898    0.248743    0.814871   10.204528   10.185617
# min    2015.0    1.000000  161.000000   78.000000   63.000000   62.000000
# 25%    2015.0    2.000000  162.000000   81.000000   74.000000   74.000000
# 50%    2015.0    3.000000  162.000000   81.000000   81.000000   80.000000
# 75%    2015.0    4.000000  162.000000   81.000000   88.000000   88.000000
# max    2015.0    5.000000  162.000000   84.000000  100.000000   99.000000
#
#                 r           ab            h      double      ...       \
# count  816.000000   816.000000   816.000000  816.000000      ...
# mean   689.240196  5516.980392  1403.776961  275.007353      ...
# std     56.509611    70.250854    56.031273   17.570819      ...
# min    573.000000  5385.000000  1324.000000  236.000000      ...
# 25%    650.000000  5463.000000  1363.000000  262.000000      ...
# 50%    689.000000  5511.000000  1383.000000  277.000000      ...
# 75%    720.000000  5571.000000  1462.000000  289.000000      ...
# max    891.000000  5649.000000  1515.000000  308.000000      ...
#
#               hra         bba          soa           e          dp  \
# count  816.000000  816.000000   816.000000  816.000000  816.000000
# mean   163.524510  468.410539  1251.134804   94.604167  145.580882
# std     19.376968   50.054467   107.026602   13.919891   18.057191
# min    110.000000  364.000000  1046.000000   75.000000  108.000000
# 25%    152.000000  425.000000  1158.250000   86.000000  133.000000
# 50%    171.000000  477.000000  1252.000000   92.000000  145.000000
# 75%    177.000000  500.000000  1342.000000   97.000000  159.000000
# max    193.000000  579.000000  1431.000000  126.000000  186.000000
#
#                fp    attendance         bpf         ppf        salary
# count  816.000000  8.160000e+02  816.000000  816.000000  8.160000e+02
# mean     0.984458  2.463405e+06  100.398284  100.428922  4.300573e+06
# std      0.002185  5.898354e+05    4.729694    4.832390  5.509518e+06
# min      0.979000  1.287054e+06   92.000000   92.000000  5.070000e+05
# 25%      0.984000  2.080145e+06   97.000000   97.000000  5.225000e+05
# 50%      0.985000  2.498596e+06  100.000000   99.000000  1.865000e+06
# 75%      0.986000  2.794891e+06  102.000000  103.000000  5.906250e+06
# max      0.988000  3.764815e+06  119.000000  118.000000  3.257100e+07
#
# [8 rows x 36 columns]

# %% [markdown]
# #### What about change in salary?

# %%
def salary_change(year):
    team_salary_year = team_salary[team_salary.year == year]
    team_salary_minusone = team_salary[team_salary.year == (year - 1)]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_total = team_salary_year.groupby('team_id')['salary'].sum() - team_salary_minusone.groupby('team_id')['salary'].sum()
    return wins.values.reshape(-1, 1), salary_total.values.reshape(-1, 1)

# %%
for year in range(1986, 2016):
    try:
        X, y = salary_change(year)
        lr.fit(X, y)
        print(f'For {year}, score is {lr.score(X, y)} and coef is {int(lr.coef_[0][0])}')
    except ValueError:
        pass
# Out:
# For 1986, score is 0.014072063452497674 and coef is 21413
# For 1987, score is 0.021523815640782873 and coef is -30866
# For 1988, score is 0.042219937143744946 and coef is 45916
# For 1989, score is 0.09375137979747639 and coef is 93729
# For 1990, score is 0.02636312474553071 and coef is -32888
# For 1991, score is 0.059486695721012506 and coef is 136280
# For 1992, score is 0.10559847835134828 and coef is 192214
# For 1994, score is 0.11574890487509228 and coef is 253068
# For 1995, score is 0.04113505556481367 and coef is 120495
# For 1996, score is 0.2558286251451177 and coef is 392173
# For 1999, score is 0.24264471518834319 and coef is 478030
# For 2000, score is 0.0366021694278752 and coef is 158088
# For 2001, score is 0.048291613011215984 and coef is 217775
# For 2002, score is 0.10484877737300291 and coef is 243821
# For 2003, score is 0.06123624411533391 and coef is 257907
# For 2004, score is 0.09188337525830592 and coef is 378660
# For 2006, score is 0.0006154160043464474 and coef is 32878
# For 2007, score is 0.016144310144636798 and coef is 154195
# For 2008, score is 0.007362539834035897 and coef is 119632
# For 2009, score is 0.034368730749988474 and coef is -221599
# For 2010, score is 0.17925971959520523 and coef is 593528
# For 2011, score is 0.06705224783303199 and coef is 398547
# For 2013, score is 0.11836961649784694 and coef is 1012951
# For 2014, score is 0.014573710259859986 and coef is 230332
# For 2015, score is 0.11808921772468628 and coef is 830263

# %%
def wins_salary_change_graph(year):
    team_salary_year = team_salary[team_salary.year == year]
    team_salary_minusone = team_salary[team_salary.year == (year - 1)]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_total = team_salary_year.groupby('team_id')['salary'].sum() - team_salary_minusone.groupby('team_id')['salary'].sum()
    plt.scatter(salary_total, wins)
    plt.ylabel("Team wins")
    plt.xlabel("Team salary change")
    plt.title(f"How does salary impact wins?\n{year} season")

# %%
wins_salary_change_graph(2006)
