# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
player = pd.read_csv('data/baseball/player.csv')
salary = pd.read_csv('data/baseball/salary.csv')
appearances = pd.read_csv('data/baseball/appearances.csv')
batting = pd.read_csv('data/baseball/batting.csv')
fielding = pd.read_csv('data/baseball/fielding.csv')
team = pd.read_csv('data/baseball/team.csv')
pitching = pd.read_csv('data/baseball/pitching.csv')

# %% [markdown]
# For the project, we are looking at the importance of salary for building a baseball team.

# %% [markdown]
# ### Distributions
#
# #### By year (individual players)

# %%
np.log(salary.groupby('player_id')['salary'].mean()).plot(kind='hist', bins=12, title='Log of mean salaries')

# %%
def distribution_salary(year):
    np.log(salary[(salary.year == year)].salary).plot(kind='hist', bins=20, title=f'Log salaries in {year}')

# %%
distribution_salary(2015)

# %%
distribution_salary(2005)

# %%
distribution_salary(1995)

# %%
distribution_salary(1985)

# %% [markdown]
# #### By year (team totals)

# %%
team_salary = team.merge(salary)
winners = team_salary[(team_salary.w / team_salary.l) >= 1]
losers = team_salary[(team_salary.w / team_salary.l) < 1]

# %%
def distribution_team_salary(year):
    np.log(winners[(winners.year == year)].groupby('team_id')['salary'].sum()).plot(
        kind='hist', bins=8, title=f'Log team salaries {year}', alpha=0.5)
    np.log(losers[(losers.year == year)].groupby('team_id')['salary'].sum()).plot(
        kind='hist', bins=8, title=f'Log team salaries {year}', alpha=0.5)
    np.log(winners[(winners.year == year) & (winners.ws_win == 'Y')].groupby('team_id')['salary'].sum()).plot(
        kind='hist', bins=8, title=f'Log team salaries {year}', alpha=0.5)

# %% [markdown]
# Blue bars represent teams with a record better than .500, orange bars are teams with less than .500.

# %%
distribution_team_salary(1985)

# %%
distribution_team_salary(1996)

# %%
distribution_team_salary(2005)

# %%
distribution_team_salary(2015)

# %% [markdown]
# ### Scatterplots and Regressions
#
# #### Do Higher Team Salaries Translate to More Wins?

# %%
team_salary = team.merge(salary)

# %%
def salary_year(year):
    team_salary_year = team_salary[team_salary.year == year]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_total = team_salary_year.groupby('team_id')['salary'].sum()
    return wins, salary_total

# %%
def wins_salary_graph(year):
    wins, salary_total = salary_year(year)
    team_salary_year = team_salary[team_salary.year == year]
    ws_win = team_salary_year[team_salary_year.ws_win == 'Y']
    plt.scatter(np.log(salary_total), wins)
    plt.scatter(np.log(ws_win.groupby('team_id')['salary'].sum()), ws_win.groupby('team_id')['w'].median())
    plt.ylabel("Team wins")
    plt.xlabel("Log team salary")
    plt.title(f"How does salary impact wins?\n{year} season")

# %%
wins_salary_graph(2015)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# /Users/jnelson/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
for year in range(1985, 2016):
    y, X = salary_year(year)
    X = np.log(X)
    X = sm.add_constant(X)
    results = smf.OLS(y, X).fit()
    print(f'\nFor {year}:\n{results.summary()}')
# Out:
# For 1985:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     3.505
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0734
# Time:                        21:41:13   Log-Likelihood:                -100.43
# No. Observations:                  26   AIC:                             204.9
# Df Residuals:                      24   BIC:                             207.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -187.4236    143.288     -1.308      0.203    -483.155     108.308
# salary        16.6673      8.902      1.872      0.073      -1.706      35.041
# ==============================================================================
# Omnibus:                        1.107   Durbin-Watson:                   2.194
# Prob(Omnibus):                  0.575   Jarque-Bera (JB):                1.028
# Skew:                          -0.324   Prob(JB):                        0.598
# Kurtosis:                       2.272   Cond. No.                         985.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1986:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.206
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.283
# Time:                        21:41:13   Log-Likelihood:                -96.298
# No. Observations:                  26   AIC:                             196.6
# Df Residuals:                      24   BIC:                             199.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -49.5747    118.766     -0.417      0.680    -294.696     195.547
# salary         8.0256      7.307      1.098      0.283      -7.056      23.107
# ==============================================================================
# Omnibus:                        1.248   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.536   Jarque-Bera (JB):                0.985
# Skew:                           0.457   Prob(JB):                        0.611
# Kurtosis:                       2.729   Cond. No.                         966.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1987:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                   0.03132
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.861
# Time:                        21:41:13   Log-Likelihood:                -95.826
# No. Observations:                  26   AIC:                             195.7
# Df Residuals:                      24   BIC:                             198.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         71.8787     51.362      1.399      0.174     -34.128     177.885
# salary         0.5662      3.199      0.177      0.861      -6.037       7.169
# ==============================================================================
# Omnibus:                        0.564   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.754   Jarque-Bera (JB):                0.630
# Skew:                          -0.105   Prob(JB):                        0.730
# Kurtosis:                       2.267   Cond. No.                         420.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1988:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.6515
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.427
# Time:                        21:41:13   Log-Likelihood:                -100.71
# No. Observations:                  26   AIC:                             205.4
# Df Residuals:                      24   BIC:                             207.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -18.2735    122.629     -0.149      0.883    -271.368     234.821
# salary         6.1027      7.560      0.807      0.427      -9.501      21.707
# ==============================================================================
# Omnibus:                        3.920   Durbin-Watson:                   1.428
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.269
# Skew:                          -0.640   Prob(JB):                        0.322
# Kurtosis:                       3.677   Cond. No.                         840.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1989:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     3.449
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0756
# Time:                        21:41:13   Log-Likelihood:                -94.476
# No. Observations:                  26   AIC:                             193.0
# Df Residuals:                      24   BIC:                             195.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -132.7017    115.019     -1.154      0.260    -370.088     104.685
# salary        13.0161      7.008      1.857      0.076      -1.448      27.481
# ==============================================================================
# Omnibus:                        1.417   Durbin-Watson:                   2.376
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                0.760
# Skew:                          -0.418   Prob(JB):                        0.684
# Kurtosis:                       3.063   Cond. No.                     1.01e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1990:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                  0.002498
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.961
# Time:                        21:41:14   Log-Likelihood:                -93.713
# No. Observations:                  26   AIC:                             191.4
# Df Residuals:                      24   BIC:                             193.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         87.3767    128.378      0.681      0.503    -177.582     352.335
# salary        -0.3858      7.720     -0.050      0.961     -16.320      15.548
# ==============================================================================
# Omnibus:                        1.396   Durbin-Watson:                   2.199
# Prob(Omnibus):                  0.498   Jarque-Bera (JB):                1.023
# Skew:                           0.476   Prob(JB):                        0.600
# Kurtosis:                       2.805   Cond. No.                     1.18e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1991:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     2.061
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.164
# Time:                        21:41:14   Log-Likelihood:                -94.417
# No. Observations:                  26   AIC:                             192.8
# Df Residuals:                      24   BIC:                             195.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -69.3722    104.696     -0.663      0.514    -285.454     146.710
# salary         8.8762      6.182      1.436      0.164      -3.883      21.636
# ==============================================================================
# Omnibus:                        0.120   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.942   Jarque-Bera (JB):                0.221
# Skew:                          -0.140   Prob(JB):                        0.895
# Kurtosis:                       2.646   Cond. No.                         954.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1992:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                   0.07768
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.783
# Time:                        21:41:14   Log-Likelihood:                -96.768
# No. Observations:                  26   AIC:                             197.5
# Df Residuals:                      24   BIC:                             200.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         53.4229     98.967      0.540      0.594    -150.834     257.680
# salary         1.6038      5.754      0.279      0.783     -10.272      13.480
# ==============================================================================
# Omnibus:                        2.880   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.237   Jarque-Bera (JB):                1.303
# Skew:                           0.035   Prob(JB):                        0.521
# Kurtosis:                       1.906   Cond. No.                         836.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1993:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     3.684
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0660
# Time:                        21:41:14   Log-Likelihood:                -107.30
# No. Observations:                  28   AIC:                             218.6
# Df Residuals:                      26   BIC:                             221.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -134.4965    112.289     -1.198      0.242    -365.310      96.317
# salary        12.5011      6.513      1.919      0.066      -0.886      25.888
# ==============================================================================
# Omnibus:                        0.005   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.998   Jarque-Bera (JB):                0.147
# Skew:                          -0.026   Prob(JB):                        0.929
# Kurtosis:                       2.649   Cond. No.                         887.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1994:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     3.868
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0600
# Time:                        21:41:14   Log-Likelihood:                -94.060
# No. Observations:                  28   AIC:                             192.1
# Df Residuals:                      26   BIC:                             194.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -109.7183     84.840     -1.293      0.207    -284.109      64.673
# salary         9.6541      4.909      1.967      0.060      -0.437      19.745
# ==============================================================================
# Omnibus:                        9.859   Durbin-Watson:                   1.569
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                8.199
# Skew:                           1.171   Prob(JB):                       0.0166
# Kurtosis:                       4.242   Cond. No.                     1.08e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 1995:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     3.629
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0679
# Time:                        21:41:14   Log-Likelihood:                -102.59
# No. Observations:                  28   AIC:                             209.2
# Df Residuals:                      26   BIC:                             211.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -120.3246    100.978     -1.192      0.244    -327.887      87.238
# salary        11.1193      5.837      1.905      0.068      -0.879      23.117
# ==============================================================================
# Omnibus:                        2.733   Durbin-Watson:                   1.554
# Prob(Omnibus):                  0.255   Jarque-Bera (JB):                1.353
# Skew:                           0.348   Prob(JB):                        0.508
# Kurtosis:                       3.821   Cond. No.                         947.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1996:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     8.617
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):            0.00688
# Time:                        21:41:14   Log-Likelihood:                -99.665
# No. Observations:                  28   AIC:                             203.3
# Df Residuals:                      26   BIC:                             206.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -184.3578     90.388     -2.040      0.052    -370.153       1.437
# salary        15.3365      5.225      2.935      0.007       4.597      26.076
# ==============================================================================
# Omnibus:                        3.267   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.195   Jarque-Bera (JB):                1.798
# Skew:                          -0.527   Prob(JB):                        0.407
# Kurtosis:                       3.657   Cond. No.                         941.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1997:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     3.830
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0612
# Time:                        21:41:14   Log-Likelihood:                -100.65
# No. Observations:                  28   AIC:                             205.3
# Df Residuals:                      26   BIC:                             208.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -66.7526     75.485     -0.884      0.385    -221.915      88.409
# salary         8.4661      4.326      1.957      0.061      -0.427      17.359
# ==============================================================================
# Omnibus:                        3.538   Durbin-Watson:                   1.607
# Prob(Omnibus):                  0.171   Jarque-Bera (JB):                1.461
# Skew:                          -0.023   Prob(JB):                        0.482
# Kurtosis:                       1.882   Cond. No.                         765.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1998:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.385
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     17.56
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):           0.000252
# Time:                        21:41:14   Log-Likelihood:                -112.90
# No. Observations:                  30   AIC:                             229.8
# Df Residuals:                      28   BIC:                             232.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -249.0007     78.784     -3.161      0.004    -410.382     -87.620
# salary        18.8720      4.504      4.190      0.000       9.646      28.098
# ==============================================================================
# Omnibus:                        1.357   Durbin-Watson:                   2.531
# Prob(Omnibus):                  0.507   Jarque-Bera (JB):                0.398
# Skew:                          -0.067   Prob(JB):                        0.819
# Kurtosis:                       3.548   Cond. No.                         702.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 1999:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.312
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     12.73
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):            0.00132
# Time:                        21:41:14   Log-Likelihood:                -112.25
# No. Observations:                  30   AIC:                             228.5
# Df Residuals:                      28   BIC:                             231.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -184.8675     74.526     -2.481      0.019    -337.528     -32.207
# salary        15.0763      4.226      3.567      0.001       6.419      23.733
# ==============================================================================
# Omnibus:                        4.309   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                1.659
# Skew:                           0.088   Prob(JB):                        0.436
# Kurtosis:                       1.861   Cond. No.                         684.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2000:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     3.141
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0872
# Time:                        21:41:14   Log-Likelihood:                -109.50
# No. Observations:                  30   AIC:                             223.0
# Df Residuals:                      28   BIC:                             225.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -42.3212     69.572     -0.608      0.548    -184.832     100.190
# salary         6.9463      3.920      1.772      0.087      -1.083      14.975
# ==============================================================================
# Omnibus:                        1.417   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                0.961
# Skew:                          -0.001   Prob(JB):                        0.619
# Kurtosis:                       2.123   Cond. No.                         704.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2001:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     2.385
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.134
# Time:                        21:41:14   Log-Likelihood:                -117.80
# No. Observations:                  30   AIC:                             239.6
# Df Residuals:                      28   BIC:                             242.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -80.9674    104.869     -0.772      0.447    -295.781     133.846
# salary         9.0342      5.850      1.544      0.134      -2.950      21.018
# ==============================================================================
# Omnibus:                        3.005   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.223   Jarque-Bera (JB):                1.872
# Skew:                           0.593   Prob(JB):                        0.392
# Kurtosis:                       3.302   Cond. No.                         813.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2002:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     6.086
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0200
# Time:                        21:41:14   Log-Likelihood:                -119.85
# No. Observations:                  30   AIC:                             243.7
# Df Residuals:                      28   BIC:                             246.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -227.6366    125.062     -1.820      0.079    -483.815      28.542
# salary        17.1721      6.961      2.467      0.020       2.914      31.430
# ==============================================================================
# Omnibus:                        0.577   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.749   Jarque-Bera (JB):                0.651
# Skew:                           0.112   Prob(JB):                        0.722
# Kurtosis:                       2.314   Cond. No.                         907.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2003:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     6.733
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0149
# Time:                        21:41:14   Log-Likelihood:                -116.61
# No. Observations:                  30   AIC:                             237.2
# Df Residuals:                      28   BIC:                             240.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -177.8648     99.777     -1.783      0.085    -382.249      26.519
# salary        14.3789      5.542      2.595      0.015       3.028      25.730
# ==============================================================================
# Omnibus:                        5.189   Durbin-Watson:                   2.323
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                3.681
# Skew:                          -0.820   Prob(JB):                        0.159
# Kurtosis:                       3.504   Cond. No.                         808.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2004:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.268
# Method:                 Least Squares   F-statistic:                     11.61
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):            0.00201
# Time:                        21:41:14   Log-Likelihood:                -115.04
# No. Observations:                  30   AIC:                             234.1
# Df Residuals:                      28   BIC:                             236.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -215.8706     87.137     -2.477      0.020    -394.363     -37.379
# salary        16.5321      4.852      3.407      0.002       6.593      26.471
# ==============================================================================
# Omnibus:                        7.224   Durbin-Watson:                   2.639
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                5.616
# Skew:                          -1.003   Prob(JB):                       0.0603
# Kurtosis:                       3.682   Cond. No.                         742.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2005:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     10.94
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):            0.00259
# Time:                        21:41:14   Log-Likelihood:                -108.59
# No. Observations:                  30   AIC:                             221.2
# Df Residuals:                      28   BIC:                             224.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -171.1024     76.245     -2.244      0.033    -327.284     -14.921
# salary        13.9903      4.230      3.307      0.003       5.325      22.655
# ==============================================================================
# Omnibus:                        0.426   Durbin-Watson:                   2.643
# Prob(Omnibus):                  0.808   Jarque-Bera (JB):                0.560
# Skew:                           0.078   Prob(JB):                        0.756
# Kurtosis:                       2.349   Cond. No.                         808.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2006:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     9.044
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):            0.00552
# Time:                        21:41:14   Log-Likelihood:                -107.19
# No. Observations:                  30   AIC:                             218.4
# Df Residuals:                      28   BIC:                             221.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -116.3826     65.644     -1.773      0.087    -250.848      18.082
# salary        10.9177      3.630      3.007      0.006       3.481      18.354
# ==============================================================================
# Omnibus:                        0.193   Durbin-Watson:                   1.741
# Prob(Omnibus):                  0.908   Jarque-Bera (JB):                0.402
# Skew:                          -0.017   Prob(JB):                        0.818
# Kurtosis:                       2.434   Cond. No.                         731.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2007:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     8.984
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):            0.00565
# Time:                        21:41:14   Log-Likelihood:                -104.77
# No. Observations:                  30   AIC:                             213.5
# Df Residuals:                      28   BIC:                             216.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -105.5301     62.262     -1.695      0.101    -233.068      22.008
# salary        10.2838      3.431      2.997      0.006       3.256      17.312
# ==============================================================================
# Omnibus:                        0.572   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.751   Jarque-Bera (JB):                0.658
# Skew:                           0.140   Prob(JB):                        0.720
# Kurtosis:                       2.331   Cond. No.                         754.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2008:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     2.220
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.147
# Time:                        21:41:14   Log-Likelihood:                -113.08
# No. Observations:                  30   AIC:                             230.2
# Df Residuals:                      28   BIC:                             233.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -41.6082     82.274     -0.506      0.617    -210.138     126.922
# salary         6.7255      4.514      1.490      0.147      -2.521      15.972
# ==============================================================================
# Omnibus:                        0.610   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.737   Jarque-Bera (JB):                0.711
# Skew:                          -0.235   Prob(JB):                        0.701
# Kurtosis:                       2.411   Cond. No.                         759.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2009:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     7.302
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0116
# Time:                        21:41:14   Log-Likelihood:                -111.68
# No. Observations:                  30   AIC:                             227.4
# Df Residuals:                      28   BIC:                             230.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -180.4254     96.766     -1.865      0.073    -378.641      17.790
# salary        14.3341      5.305      2.702      0.012       3.468      25.200
# ==============================================================================
# Omnibus:                        3.362   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.186   Jarque-Bera (JB):                1.817
# Skew:                          -0.321   Prob(JB):                        0.403
# Kurtosis:                       1.979   Cond. No.                         936.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2010:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     4.355
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0461
# Time:                        21:41:14   Log-Likelihood:                -111.84
# No. Observations:                  30   AIC:                             227.7
# Df Residuals:                      28   BIC:                             230.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -100.8202     87.142     -1.157      0.257    -279.322      77.682
# salary         9.9661      4.775      2.087      0.046       0.184      19.748
# ==============================================================================
# Omnibus:                        2.665   Durbin-Watson:                   2.651
# Prob(Omnibus):                  0.264   Jarque-Bera (JB):                1.368
# Skew:                          -0.141   Prob(JB):                        0.505
# Kurtosis:                       1.993   Cond. No.                         839.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2011:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     4.029
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0545
# Time:                        21:41:14   Log-Likelihood:                -113.09
# No. Observations:                  30   AIC:                             230.2
# Df Residuals:                      28   BIC:                             233.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -85.7747     83.089     -1.032      0.311    -255.975      84.426
# salary         9.1349      4.551      2.007      0.054      -0.187      18.457
# ==============================================================================
# Omnibus:                        0.432   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.806   Jarque-Bera (JB):                0.562
# Skew:                          -0.226   Prob(JB):                        0.755
# Kurtosis:                       2.505   Cond. No.                         767.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2012:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.110
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.301
# Time:                        21:41:14   Log-Likelihood:                -115.86
# No. Observations:                  30   AIC:                             235.7
# Df Residuals:                      28   BIC:                             238.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -44.0449    118.712     -0.371      0.713    -287.215     199.125
# salary         6.8188      6.472      1.054      0.301      -6.439      20.077
# ==============================================================================
# Omnibus:                        2.760   Durbin-Watson:                   2.430
# Prob(Omnibus):                  0.252   Jarque-Bera (JB):                1.564
# Skew:                          -0.267   Prob(JB):                        0.458
# Kurtosis:                       2.017   Cond. No.                     1.00e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# For 2013:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     6.103
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0199
# Time:                        21:41:14   Log-Likelihood:                -114.28
# No. Observations:                  30   AIC:                             232.6
# Df Residuals:                      28   BIC:                             235.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -100.1661     73.378     -1.365      0.183    -250.473      50.141
# salary         9.8943      4.005      2.470      0.020       1.690      18.098
# ==============================================================================
# Omnibus:                        3.576   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.167   Jarque-Bera (JB):                1.496
# Skew:                           0.022   Prob(JB):                        0.473
# Kurtosis:                       1.907   Cond. No.                         654.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2014:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     3.404
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0757
# Time:                        21:41:14   Log-Likelihood:                -108.19
# No. Observations:                  30   AIC:                             220.4
# Df Residuals:                      28   BIC:                             223.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -62.5709     77.840     -0.804      0.428    -222.019      96.878
# salary         7.8007      4.228      1.845      0.076      -0.861      16.462
# ==============================================================================
# Omnibus:                        1.531   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.465   Jarque-Bera (JB):                1.116
# Skew:                          -0.207   Prob(JB):                        0.572
# Kurtosis:                       2.151   Cond. No.                         853.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# For 2015:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      w   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.767
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.194
# Time:                        21:41:14   Log-Likelihood:                -111.55
# No. Observations:                  30   AIC:                             227.1
# Df Residuals:                      28   BIC:                             229.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -59.1532    105.419     -0.561      0.579    -275.094     156.788
# salary         7.5649      5.691      1.329      0.194      -4.092      19.222
# ==============================================================================
# Omnibus:                        1.067   Durbin-Watson:                   2.247
# Prob(Omnibus):                  0.586   Jarque-Bera (JB):                0.882
# Skew:                           0.134   Prob(JB):                        0.643
# Kurtosis:                       2.204   Cond. No.                     1.04e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
wins_salary_graph(1996)

# %%
wins_salary_graph(1998)

# %% [markdown]
# #### What about change in salary?

# %%
def salary_change(year):
    team_salary_year = team_salary[team_salary.year == year]
    team_salary_minusone = team_salary[team_salary.year == (year - 1)]
    wins = team_salary_year.groupby('team_id')['w'].median()
    salary_change = (
        (team_salary_year.groupby('team_id')['salary'].sum() - team_salary_minusone.groupby('team_id')['salary'].sum())
        / team_salary_minusone.groupby('team_id')['salary'].sum()
    ) 
    return wins.values.reshape(-1, 1), salary_change.values.reshape(-1, 1)

# %%
def wins_salary_change_graph(year):
    y, X = salary_change(year)
    plt.scatter(X*100, y)
    plt.ylabel("Team wins")
    plt.xlabel("Team salary % change")
    plt.title(f"How does salary impact wins?\n{year} season")

# %%
for year in range(1986, 2016):
    try:
        y, X = salary_change(year)
        X = sm.add_constant(X)
        results = sm.OLS(y, X).fit()
        print(f'For {year}: {results.summary()}')
    except ValueError:
        pass
# Out:
# For 1986:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.041
# Method:                 Least Squares   F-statistic:                   0.01103
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.917
# Time:                        21:41:14   Log-Likelihood:                -96.929
# No. Observations:                  26   AIC:                             197.9
# Df Residuals:                      24   BIC:                             200.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.6289      2.915     27.657      0.000      74.612      86.646
# x1             1.1728     11.166      0.105      0.917     -21.873      24.218
# ==============================================================================
# Omnibus:                        2.438   Durbin-Watson:                   1.618
# Prob(Omnibus):                  0.296   Jarque-Bera (JB):                1.594
# Skew:                           0.606   Prob(JB):                        0.451
# Kurtosis:                       3.043   Cond. No.                         5.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1987:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                    0.1656
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.688
# Time:                        21:41:14   Log-Likelihood:                -95.753
# No. Observations:                  26   AIC:                             195.5
# Df Residuals:                      24   BIC:                             198.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.5210      2.242     35.908      0.000      75.893      85.149
# x1            -3.3333      8.192     -0.407      0.688     -20.241      13.575
# ==============================================================================
# Omnibus:                        0.689   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.709   Jarque-Bera (JB):                0.671
# Skew:                          -0.001   Prob(JB):                        0.715
# Kurtosis:                       2.213   Cond. No.                         4.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1988:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.7596
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.392
# Time:                        21:41:14   Log-Likelihood:                -100.65
# No. Observations:                  26   AIC:                             205.3
# Df Residuals:                      24   BIC:                             207.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.4214      2.514     32.389      0.000      76.233      86.610
# x1            -1.9452      2.232     -0.872      0.392      -6.552       2.661
# ==============================================================================
# Omnibus:                        3.726   Durbin-Watson:                   1.291
# Prob(Omnibus):                  0.155   Jarque-Bera (JB):                2.163
# Skew:                          -0.645   Prob(JB):                        0.339
# Kurtosis:                       3.574   Cond. No.                         1.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1989:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.8473
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.366
# Time:                        21:41:14   Log-Likelihood:                -95.771
# No. Observations:                  26   AIC:                             195.5
# Df Residuals:                      24   BIC:                             198.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         79.5416      2.448     32.499      0.000      74.490      84.593
# x1             5.1942      5.643      0.920      0.366      -6.452      16.841
# ==============================================================================
# Omnibus:                        0.936   Durbin-Watson:                   2.348
# Prob(Omnibus):                  0.626   Jarque-Bera (JB):                0.896
# Skew:                          -0.267   Prob(JB):                        0.639
# Kurtosis:                       2.264   Cond. No.                         3.09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1990:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.6238
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.437
# Time:                        21:41:14   Log-Likelihood:                -93.380
# No. Observations:                  26   AIC:                             190.8
# Df Residuals:                      24   BIC:                             193.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         83.2974      3.458     24.087      0.000      76.160      90.435
# x1            -9.2741     11.742     -0.790      0.437     -33.508      14.960
# ==============================================================================
# Omnibus:                        1.620   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.445   Jarque-Bera (JB):                1.009
# Skew:                           0.482   Prob(JB):                        0.604
# Kurtosis:                       2.978   Cond. No.                         6.98
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1991:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8733
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.359
# Time:                        21:41:14   Log-Likelihood:                -95.024
# No. Observations:                  26   AIC:                             194.0
# Df Residuals:                      24   BIC:                             196.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         78.6838      3.064     25.681      0.000      72.360      85.007
# x1             5.6008      5.993      0.935      0.359      -6.769      17.970
# ==============================================================================
# Omnibus:                        0.883   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.643   Jarque-Bera (JB):                0.622
# Skew:                          -0.367   Prob(JB):                        0.733
# Kurtosis:                       2.813   Cond. No.                         3.69
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1992:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     4.683
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0406
# Time:                        21:41:14   Log-Likelihood:                -94.492
# No. Observations:                  26   AIC:                             193.0
# Df Residuals:                      24   BIC:                             195.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         76.5846      2.768     27.667      0.000      70.871      82.298
# x1            13.0329      6.022      2.164      0.041       0.603      25.462
# ==============================================================================
# Omnibus:                        0.191   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.909   Jarque-Bera (JB):                0.383
# Skew:                          -0.132   Prob(JB):                        0.826
# Kurtosis:                       2.467   Cond. No.                         3.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1993:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):                nan
# Time:                        21:41:15   Log-Likelihood:                    nan
# No. Observations:                  28   AIC:                               nan
# Df Residuals:                      28   BIC:                               nan
# Df Model:                          -1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1                nan        nan        nan        nan         nan         nan
# const             nan        nan        nan        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1994:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.7914
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.382
# Time:                        21:41:15   Log-Likelihood:                -95.582
# No. Observations:                  28   AIC:                             195.2
# Df Residuals:                      26   BIC:                             197.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         56.7874      1.486     38.226      0.000      53.734      59.841
# x1             4.2479      4.775      0.890      0.382      -5.567      14.063
# ==============================================================================
# Omnibus:                        3.442   Durbin-Watson:                   1.608
# Prob(Omnibus):                  0.179   Jarque-Bera (JB):                2.951
# Skew:                           0.710   Prob(JB):                        0.229
# Kurtosis:                       2.285   Cond. No.                         3.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1995:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.195
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.284
# Time:                        21:41:15   Log-Likelihood:                -103.79
# No. Observations:                  28   AIC:                             211.6
# Df Residuals:                      26   BIC:                             214.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         71.6267      1.963     36.497      0.000      67.593      75.661
# x1             8.9933      8.228      1.093      0.284      -7.919      25.906
# ==============================================================================
# Omnibus:                        3.350   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.187   Jarque-Bera (JB):                2.103
# Skew:                           0.651   Prob(JB):                        0.349
# Kurtosis:                       3.325   Cond. No.                         4.27
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 1996:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     7.511
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0109
# Time:                        21:41:15   Log-Likelihood:                -100.12
# No. Observations:                  28   AIC:                             204.2
# Df Residuals:                      26   BIC:                             206.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.3419      1.708     47.025      0.000      76.830      83.854
# x1            21.7839      7.949      2.741      0.011       5.445      38.123
# ==============================================================================
# Omnibus:                        1.220   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.543   Jarque-Bera (JB):                1.165
# Skew:                          -0.421   Prob(JB):                        0.559
# Kurtosis:                       2.463   Cond. No.                         4.69
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/jnelson/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py:1574: RuntimeWarning: invalid value encountered in greater
#   return (S > tol).sum(axis=-1)
# /Users/jnelson/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/jnelson/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/jnelson/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# For 1999:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     3.686
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0651
# Time:                        21:41:15   Log-Likelihood:                -116.01
# No. Observations:                  30   AIC:                             236.0
# Df Residuals:                      28   BIC:                             238.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         78.3707      2.552     30.706      0.000      73.142      83.599
# x1            12.5513      6.537      1.920      0.065      -0.840      25.942
# ==============================================================================
# Omnibus:                        6.604   Durbin-Watson:                   1.746
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                2.103
# Skew:                           0.178   Prob(JB):                        0.349
# Kurtosis:                       1.753   Cond. No.                         3.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2000:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                   0.02921
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.866
# Time:                        21:41:15   Log-Likelihood:                -111.08
# No. Observations:                  30   AIC:                             226.2
# Df Residuals:                      28   BIC:                             229.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.1252      2.168     37.424      0.000      76.685      85.566
# x1            -1.3165      7.703     -0.171      0.866     -17.095      14.462
# ==============================================================================
# Omnibus:                        6.338   Durbin-Watson:                   1.655
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                1.938
# Skew:                           0.003   Prob(JB):                        0.380
# Kurtosis:                       1.755   Cond. No.                         4.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2001:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                  0.006712
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.935
# Time:                        21:41:15   Log-Likelihood:                -119.02
# No. Observations:                  30   AIC:                             242.0
# Df Residuals:                      28   BIC:                             244.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.0754      2.974     27.257      0.000      74.982      87.168
# x1            -0.6143      7.498     -0.082      0.935     -15.974      14.745
# ==============================================================================
# Omnibus:                        1.500   Durbin-Watson:                   2.231
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                0.925
# Skew:                           0.430   Prob(JB):                        0.630
# Kurtosis:                       3.018   Cond. No.                         3.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2002:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     2.825
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.104
# Time:                        21:41:15   Log-Likelihood:                -121.36
# No. Observations:                  30   AIC:                             246.7
# Df Residuals:                      28   BIC:                             249.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         79.4874      2.733     29.089      0.000      73.890      85.085
# x1            20.9254     12.450      1.681      0.104      -4.577      46.428
# ==============================================================================
# Omnibus:                        1.698   Durbin-Watson:                   2.260
# Prob(Omnibus):                  0.428   Jarque-Bera (JB):                1.177
# Skew:                          -0.212   Prob(JB):                        0.555
# Kurtosis:                       2.127   Cond. No.                         4.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2003:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     2.036
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.165
# Time:                        21:41:15   Log-Likelihood:                -118.79
# No. Observations:                  30   AIC:                             241.6
# Df Residuals:                      28   BIC:                             244.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         79.9627      2.499     31.998      0.000      74.844      85.082
# x1            15.8811     11.130      1.427      0.165      -6.917      38.680
# ==============================================================================
# Omnibus:                        2.383   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.304   Jarque-Bera (JB):                1.628
# Skew:                          -0.570   Prob(JB):                        0.443
# Kurtosis:                       3.041   Cond. No.                         4.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2004:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     1.702
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.203
# Time:                        21:41:15   Log-Likelihood:                -119.36
# No. Observations:                  30   AIC:                             242.7
# Df Residuals:                      28   BIC:                             245.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.1785      2.451     33.119      0.000      76.158      86.199
# x1            13.6945     10.497      1.305      0.203      -7.808      35.197
# ==============================================================================
# Omnibus:                        1.144   Durbin-Watson:                   3.091
# Prob(Omnibus):                  0.564   Jarque-Bera (JB):                1.116
# Skew:                          -0.361   Prob(JB):                        0.572
# Kurtosis:                       2.391   Cond. No.                         4.30
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2006:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.034
# Method:                 Least Squares   F-statistic:                   0.04508
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.833
# Time:                        21:41:15   Log-Likelihood:                -111.36
# No. Observations:                  30   AIC:                             226.7
# Df Residuals:                      28   BIC:                             229.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.1329      2.029     39.982      0.000      76.976      85.290
# x1            -1.7442      8.215     -0.212      0.833     -18.572      15.083
# ==============================================================================
# Omnibus:                        0.934   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.627   Jarque-Bera (JB):                0.844
# Skew:                          -0.160   Prob(JB):                        0.656
# Kurtosis:                       2.243   Cond. No.                         4.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2007:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.034
# Method:                 Least Squares   F-statistic:                   0.04329
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.837
# Time:                        21:41:15   Log-Likelihood:                -108.92
# No. Observations:                  30   AIC:                             221.8
# Df Residuals:                      28   BIC:                             224.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.1667      1.841     44.095      0.000      77.396      84.937
# x1            -1.4146      6.799     -0.208      0.837     -15.342      12.513
# ==============================================================================
# Omnibus:                        7.591   Durbin-Watson:                   2.295
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):                2.096
# Skew:                           0.018   Prob(JB):                        0.351
# Kurtosis:                       1.706   Cond. No.                         3.98
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2008:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                   0.02002
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.889
# Time:                        21:41:15   Log-Likelihood:                -114.22
# No. Observations:                  30   AIC:                             232.4
# Df Residuals:                      28   BIC:                             235.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.8020      2.259     35.775      0.000      76.175      85.429
# x1             1.2034      8.506      0.141      0.889     -16.221      18.627
# ==============================================================================
# Omnibus:                        1.411   Durbin-Watson:                   1.485
# Prob(Omnibus):                  0.494   Jarque-Bera (JB):                1.153
# Skew:                          -0.274   Prob(JB):                        0.562
# Kurtosis:                       2.212   Cond. No.                         4.18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2009:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.032
# Method:                 Least Squares   F-statistic:                    0.1123
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.740
# Time:                        21:41:15   Log-Likelihood:                -115.10
# No. Observations:                  30   AIC:                             234.2
# Df Residuals:                      28   BIC:                             237.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.1290      2.155     37.645      0.000      76.714      85.543
# x1            -3.4951     10.430     -0.335      0.740     -24.860      17.870
# ==============================================================================
# Omnibus:                        1.667   Durbin-Watson:                   2.068
# Prob(Omnibus):                  0.434   Jarque-Bera (JB):                1.167
# Skew:                          -0.211   Prob(JB):                        0.558
# Kurtosis:                       2.131   Cond. No.                         4.93
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2010:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     4.712
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0386
# Time:                        21:41:15   Log-Likelihood:                -111.68
# No. Observations:                  30   AIC:                             227.4
# Df Residuals:                      28   BIC:                             230.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.5073      1.905     42.254      0.000      76.604      84.410
# x1            20.5546      9.469      2.171      0.039       1.157      39.952
# ==============================================================================
# Omnibus:                        3.261   Durbin-Watson:                   2.546
# Prob(Omnibus):                  0.196   Jarque-Bera (JB):                1.832
# Skew:                          -0.337   Prob(JB):                        0.400
# Kurtosis:                       1.995   Cond. No.                         5.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2011:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.030
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.319
# Time:                        21:41:15   Log-Likelihood:                -114.57
# No. Observations:                  30   AIC:                             233.1
# Df Residuals:                      28   BIC:                             235.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.6286      2.110     38.221      0.000      76.307      84.950
# x1             9.5234      9.386      1.015      0.319      -9.703      28.749
# ==============================================================================
# Omnibus:                        1.583   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.453   Jarque-Bera (JB):                1.013
# Skew:                          -0.012   Prob(JB):                        0.602
# Kurtosis:                       2.100   Cond. No.                         4.51
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2013:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     4.803
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):             0.0369
# Time:                        21:41:15   Log-Likelihood:                -114.86
# No. Observations:                  30   AIC:                             233.7
# Df Residuals:                      28   BIC:                             236.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.4093      2.123     37.878      0.000      76.061      84.758
# x1            12.1641      5.550      2.192      0.037       0.795      23.533
# ==============================================================================
# Omnibus:                        2.057   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.155
# Skew:                          -0.044   Prob(JB):                        0.561
# Kurtosis:                       2.043   Cond. No.                         2.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2014:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                    0.1356
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.715
# Time:                        21:41:15   Log-Likelihood:                -109.84
# No. Observations:                  30   AIC:                             223.7
# Df Residuals:                      28   BIC:                             226.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.3108      1.969     41.289      0.000      77.277      85.345
# x1            -2.5222      6.850     -0.368      0.715     -16.554      11.509
# ==============================================================================
# Omnibus:                        2.971   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.226   Jarque-Bera (JB):                1.370
# Skew:                           0.012   Prob(JB):                        0.504
# Kurtosis:                       1.953   Cond. No.                         3.91
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# For 2015:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     2.233
# Date:                Mon, 06 Nov 2017   Prob (F-statistic):              0.146
# Time:                        21:41:15   Log-Likelihood:                -111.32
# No. Observations:                  30   AIC:                             226.6
# Df Residuals:                      28   BIC:                             229.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         79.4815      2.117     37.545      0.000      75.145      83.818
# x1             8.9993      6.022      1.494      0.146      -3.336      21.334
# ==============================================================================
# Omnibus:                        2.393   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.302   Jarque-Bera (JB):                1.341
# Skew:                           0.180   Prob(JB):                        0.511
# Kurtosis:                       2.028   Cond. No.                         3.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
wins_salary_change_graph(1992)

# %% [markdown]
# There does not seem to be much of a relationship between team performance and a change in team salary from the previous year.

# %% [markdown]
# ### Salary by Position

# %%
appearances[appearances.year > 1984].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38746 entries, 62205 to 100950
# Data columns (total 22 columns):
# year         38746 non-null int64
# team_id      38746 non-null object
# league_id    38746 non-null object
# player_id    38746 non-null object
# g_all        38543 non-null float64
# gs           38543 non-null float64
# g_batting    38746 non-null int64
# g_defense    38543 non-null float64
# g_p          38746 non-null int64
# g_c          38746 non-null int64
# g_1b         38746 non-null int64
# g_2b         38746 non-null int64
# g_3b         38746 non-null int64
# g_ss         38746 non-null int64
# g_lf         38746 non-null int64
# g_cf         38746 non-null int64
# g_rf         38746 non-null int64
# g_of         38746 non-null int64
# g_dh         38746 non-null float64
# g_ph         38746 non-null float64
# g_pr         34360 non-null float64
# str_pos      38746 non-null object
# dtypes: float64(6), int64(12), object(4)
# memory usage: 6.8+ MB

# %%
appearances['str_pos'] = appearances[['g_p', 'g_c', 'g_1b', 'g_2b', 'g_3b', 'g_ss',
                                'g_lf', 'g_cf', 'g_rf', 'g_dh']].idxmax(axis=1).str.replace('g_', '')

# %%
appearances[appearances.year > 1984].groupby('str_pos').size()
# Out:
# str_pos
# 1b     2171
# 2b     2308
# 3b     2230
# c      3172
# cf     1978
# dh      810
# lf     2857
# p     18971
# rf     2250
# ss     1999
# dtype: int64

# %%
app_salary = appearances.merge(salary)

# %%
app_salary[app_salary.year == 2015].groupby('str_pos')['salary'].median() / 1000000
# Out:
# str_pos
# 1b    3.10000
# 2b    1.07500
# 3b    2.52500
# c     1.03750
# cf    1.65000
# dh    6.58300
# lf    2.10000
# p     1.48000
# rf    4.10000
# ss    1.44375
# Name: salary, dtype: float64

# %%
positions = {}
for pos in ['p', 'c', '1b', '2b', '3b', 'ss', 'lf', 'cf', 'rf', 'dh']:
    positions[(pos.replace('', ''))] = app_salary[app_salary.str_pos == pos]

# %%
def distribution_salary_pos(year, pos):
    pos_df = app_salary[app_salary.str_pos == pos]
    np.log(pos_df[(pos_df.year == year)].groupby('player_id')['salary'].mean()).plot(
        kind='hist', bins=10, title=f'Log salaries for {pos} in {year}', alpha=0.5)

# %%
distribution_salary_pos(2015, '1b')
distribution_salary_pos(2015, 'dh')
distribution_salary_pos(2015, '2b')
